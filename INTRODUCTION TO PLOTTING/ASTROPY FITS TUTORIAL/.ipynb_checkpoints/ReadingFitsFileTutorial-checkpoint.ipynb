# %% [markdown]
# In this file I will get familiar with reading in a fits image
#
#
# This tutorial is from: https://learn.astropy.org/tutorials/FITS-tables.html

# %%
import numpy as np
from astropy.io import fits
from astropy.table import Table
from matplotlib.colors import LogNorm

# Set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Font sizes
title_fs = 25
axis_label_fs = 20
axis_num_fs = 20
legend_fs = 20
cbar_fs = 20

# %% [markdown]
# ## Import the file

# %% [markdown]
# ### Import the file if it is already in the directory

# %%
event_filename = 'chandra_events.fits'

# %% [markdown]
# ### You can also do it directly from the notebook

# %%
# from astropy.utils.data import download_file

# event_filename = download_file('http://data.astropy.org/tutorials/FITS-tables/chandra_events.fits', 
#                                cache=True)

# %% [markdown]
# ## Opening the FITS file and viewing table contents
# Since the file is big, let's open it with memmap=True to prevent RAM storage issues.

# %%
hdu_list = fits.open(event_filename, memmap=True)

# %%
hdu_list.info()
# Out:
# Filename: chandra_events.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      30   ()
#   1  EVENTS        1 BinTableHDU    890   483964R x 19C   [1D, 1I, 1I, 1J, 1I, 1I, 1I, 1I, 1E, 1E, 1E, 1E, 1J, 1J, 1E, 1J, 1I, 1I, 32X]
#   2  GTI           3 BinTableHDU     28   1R x 2C   [1D, 1D]
#   3  GTI           2 BinTableHDU     28   1R x 2C   [1D, 1D]
#   4  GTI           1 BinTableHDU     28   1R x 2C   [1D, 1D]
#   5  GTI           0 BinTableHDU     28   1R x 2C   [1D, 1D]
#   6  GTI           6 BinTableHDU     28   1R x 2C   [1D, 1D]

# %% [markdown]
# ## Print column names

# %%
print(hdu_list[1].columns)
# Out:
# ColDefs(
#     name = 'time'; format = '1D'; unit = 's'
#     name = 'ccd_id'; format = '1I'
#     name = 'node_id'; format = '1I'
#     name = 'expno'; format = '1J'
#     name = 'chipx'; format = '1I'; unit = 'pixel'; coord_type = 'CPCX'; coord_unit = 'mm'; coord_ref_point = 0.5; coord_ref_value = 0.0; coord_inc = 0.023987
#     name = 'chipy'; format = '1I'; unit = 'pixel'; coord_type = 'CPCY'; coord_unit = 'mm'; coord_ref_point = 0.5; coord_ref_value = 0.0; coord_inc = 0.023987
#     name = 'tdetx'; format = '1I'; unit = 'pixel'
#     name = 'tdety'; format = '1I'; unit = 'pixel'
#     name = 'detx'; format = '1E'; unit = 'pixel'; coord_type = 'LONG-TAN'; coord_unit = 'deg'; coord_ref_point = 4096.5; coord_ref_value = 0.0; coord_inc = 0.00013666666666667
#     name = 'dety'; format = '1E'; unit = 'pixel'; coord_type = 'NPOL-TAN'; coord_unit = 'deg'; coord_ref_point = 4096.5; coord_ref_value = 0.0; coord_inc = 0.00013666666666667
#     name = 'x'; format = '1E'; unit = 'pixel'; coord_type = 'RA---TAN'; coord_unit = 'deg'; coord_ref_point = 4096.5; coord_ref_value = 266.41519201128; coord_inc = -0.00013666666666667
#     name = 'y'; format = '1E'; unit = 'pixel'; coord_type = 'DEC--TAN'; coord_unit = 'deg'; coord_ref_point = 4096.5; coord_ref_value = -29.012248288366; coord_inc = 0.00013666666666667
#     name = 'pha'; format = '1J'; unit = 'adu'; null = 0
#     name = 'pha_ro'; format = '1J'; unit = 'adu'; null = 0
#     name = 'energy'; format = '1E'; unit = 'eV'
#     name = 'pi'; format = '1J'; unit = 'chan'; null = 0
#     name = 'fltgrade'; format = '1I'
#     name = 'grade'; format = '1I'
#     name = 'status'; format = '32X'
# )

# %% [markdown]
# ## Convert it to an astropy table

# %%
evt_data = Table(hdu_list[1].data)

# %%
header = hdu_list[1].header
header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   64 / width of table in bytes
# NAXIS2  =               483964 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   19 / number of fields in each row
# EXTNAME = 'EVENTS  '           / name of this binary table extension
# HDUNAME = 'EVENTS  '           / ASCDM block name
# TTYPE1  = 'time    '           / S/C TT corresponding to mid-exposure
# TFORM1  = '1D      '           / format of field
# TUNIT1  = 's       '
# TTYPE2  = 'ccd_id  '           / CCD reporting event
# TFORM2  = '1I      '           / format of field
# TLMIN2  =                    0
# TLMAX2  =                    9
# TTYPE3  = 'node_id '           / CCD serial readout amplifier node
# TFORM3  = '1I      '           / format of field
# TLMIN3  =                    0
# TLMAX3  =                    3
# TTYPE4  = 'expno   '           / Exposure number of CCD frame containing event
# TFORM4  = '1J      '           / format of field
# TLMIN4  =                    0
# TTYPE5  = 'chipx   '           / Chip coords
# TFORM5  = '1I      '           / format of field
# TUNIT5  = 'pixel   '
# TTYPE6  = 'chipy   '           / Chip coords
# TFORM6  = '1I      '           / format of field
# TUNIT6  = 'pixel   '
# TLMIN5  =                    1
# TLMAX5  =                 1024
# TLMIN6  =                    1
# TLMAX6  =                 1024
# TTYPE7  = 'tdetx   '           / ACIS tiled detector coordinates
# TFORM7  = '1I      '           / format of field
# TUNIT7  = 'pixel   '
# TTYPE8  = 'tdety   '           / ACIS tiled detector coordinates
# TFORM8  = '1I      '           / format of field
# TUNIT8  = 'pixel   '
# TLMIN7  =                    1
# TLMAX7  =                 8192
# TLMIN8  =                    1
# TLMAX8  =                 8192
# TTYPE9  = 'detx    '           / ACIS detector coordinates
# TFORM9  = '1E      '           / format of field
# TUNIT9  = 'pixel   '
# TTYPE10 = 'dety    '           / ACIS detector coordinates
# TFORM10 = '1E      '           / format of field
# TUNIT10 = 'pixel   '
# TLMIN9  =        5.0000000E-01
# TLMAX9  =        8.1925000E+03
# TLMIN10 =        5.0000000E-01
# TLMAX10 =        8.1925000E+03
# TTYPE11 = 'x       '           / sky coordinates
# TFORM11 = '1E      '           / format of field
# TUNIT11 = 'pixel   '
# TTYPE12 = 'y       '           / sky coordinates
# TFORM12 = '1E      '           / format of field
# TUNIT12 = 'pixel   '
# TLMIN11 =        5.0000000E-01
# TLMAX11 =        8.1925000E+03
# TLMIN12 =        5.0000000E-01
# TLMAX12 =        8.1925000E+03
# TTYPE13 = 'pha     '           / total pulse height of event
# TFORM13 = '1J      '           / format of field
# TUNIT13 = 'adu     '
# TLMIN13 =                    0
# TLMAX13 =                36855
# TNULL13 =                    0
# TTYPE14 = 'pha_ro  '           / total read-out pulse height of event
# TFORM14 = '1J      '           / format of field
# TUNIT14 = 'adu     '
# TLMIN14 =                    0
# TLMAX14 =                36855
# TNULL14 =                    0
# TTYPE15 = 'energy  '           / nominal energy of event (eV)
# TFORM15 = '1E      '           / format of field
# TUNIT15 = 'eV      '
# TLMIN15 =        0.0000000E+00
# TLMAX15 =        1.0000000E+06
# TTYPE16 = 'pi      '           / pulse invariant energy of event
# TFORM16 = '1J      '           / format of field
# TUNIT16 = 'chan    '
# TLMIN16 =                    1
# TLMAX16 =                 1024
# TNULL16 =                    0
# TTYPE17 = 'fltgrade'           / event grade, flight system
# TFORM17 = '1I      '           / format of field
# TLMIN17 =                    0
# TLMAX17 =                  255
# TTYPE18 = 'grade   '           / binned event grade
# TFORM18 = '1I      '           / format of field
# TLMIN18 =                    0
# TLMAX18 =                    7
# TTYPE19 = 'status  '           / event status bits
# TFORM19 = '32X     '           / format of field
# COMMENT                               +------------------+
# COMMENT                               | AXAF FITS   File |
# COMMENT                               +------------------+
# COMMENT  *********************************************************
# COMMENT  >    This file is written following certain AXAF-ASC    <
# COMMENT  >    conventions which are documented in ASC-FITS-2.0   <
# COMMENT  *********************************************************
# COMMENT
# COMMENT                        / Configuration control block--------------------
# COMMENT
# ORIGIN  = 'ASC     '           / Source of FITS file
# CREATOR = 'cxc - Version DS 8.5' / tool that created this output
# ASCDSVER= '8.5.1.1 '           / Processing system revision
# ASOLFILE= 'pcadf238623220N003_asol1.fits'
# THRFILE = 'acisD2005-07-01evtspltN0002.fits'
# TLMVER  = 'P009    '           / Telemetry revision number (IP&CL)
# REVISION=                    3 / Processing version of data
# CHECKSUM= '9AN6I3K399K3G9K3'   / HDU checksum updated 2012-12-26T17:20:49
# DATASUM = '3138507882'         / data unit checksum updated 2012-12-26T17:20:20
# CONTENT = 'EVT2    '           / What data product
# HDUSPEC = 'ACIS Telemetry Products: Level 0 to ASC Archive ICD Rev 2.11' / ICD r
# HDUDOC  = 'ASC-FITS-2.0: McDowell, Rots: ASC FITS File Designers Guide'
# HDUVERS = '1.0.0   '
# HDUCLASS= 'OGIP    '
# HDUCLAS1= 'EVENTS  '
# HDUCLAS2= 'ACCEPTED'
# PIX_ADJ = 'EDSER   '           / Subpixel adjustment algorithm
# RAND_SKY=  0.0000000000000E+00
# SUBPIXFL= 'acisD1999-07-22subpixN0001.fits'
# RAND_PI =  1.0000000000000E+00
# COMMENT This FITS file may contain long string keyword values that are
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# COMMENT on subsequent keywords whose name = 'CONTINUE'
# COMMENT
# COMMENT                        / Time information block-------------------------
# COMMENT
# DATE    = '2012-12-26T17:19:59' / Date and time of file creation
# MJD_OBS =  5.3575832267548E+04 / Modified Julian date of observation
# DS_IDENT= 'ADS/Sa.CXO#obs/05950' / dataset identifier
# DATE-OBS= '2005-07-24T19:58:27' / Observation start date
# DATE-END= '2005-07-25T10:07:50' / Observation end date
# TIMESYS = 'TT      '           / Time system
# MJDREF  =  5.0814000000000E+04 / [d] MJD zero point for times
# TIMEZERO=  0.0000000000000E+00 / [s] Clock correction
# TIMEUNIT= 's       '           / Time unit
# BTIMNULL=  2.3489256849529E+08 / Basic Time offset (s)
# BTIMRATE=  2.5625001175100E-01 / Basic Time clock rate (s / VCDUcount)
# BTIMDRFT= -1.3668302449438E-18 / Basic Time clock drift (s / VCDUcount^2)
# BTIMCORR=  0.0000000000000E+00 / Correction applied to Basic Time rate (s)
# TIMEREF = 'LOCAL   '           / Time reference (barycenter/local)
# TASSIGN = 'SATELLITE'          / Time assigned by clock
# CLOCKAPP=                    T / default
# TIERRELA=  1.0000000000000E-09 / default
# TIERABSO=  5.0000000000000E-05 / default
# TIMVERSN= 'ASC-FITS-2'         / Timing system definition
# TSTART  =  2.3862230791619E+08 / [s] Observation start time (MET)
# TSTOP   =  2.3867327091852E+08 / [s] Observation end time (MET)
# OBS_MODE= 'POINTING'           / Observation mode
# STARTOBT=  0.0000000000000E+00 / On-Board MET close to STARTMJF and STARTMNF
# TIMEPIXR=  5.0000000000000E-01 / default
# DATACLAS= 'OBSERVED'           / default
# RADESYS = 'ICRS    '           / default
# TIMEDEL =  3.1410400000000E+00 / [s] timedel Lev1
# COMMENT
# COMMENT                        / Observation information block------------------
# COMMENT
# MISSION = 'AXAF    '           / Mission
# TELESCOP= 'CHANDRA '           / Telescope
# SIM_X   = -7.8090834371673E-01 / [mm] SIM focus pos
# SIM_Y   =  0.0000000000000E+00 / [mm] SIM orthogonal axis pos
# SIM_Z   = -2.3358743446083E+02 / [mm] SIM translation stage pos
# FOC_LEN =  1.0070000000000E+04 / [mm] HRMA focal length
# INSTRUME= 'ACIS    '           / Instrument
# GRATING = 'NONE    '           / Grating
# DETNAM  = 'ACIS-01236'         / Detector
# RA_PNT  =  2.6641519201128E+02 / [deg] Pointing RA
# DEC_PNT = -2.9012248288366E+01 / [deg] Pointing Dec
# ROLL_PNT=  2.7674669390386E+02 / [deg] Pointing Roll
# RA_TARG =  2.6641666700000E+02 / [deg] Observer's specified target RA
# DEC_TARG= -2.9007778000000E+01 / [deg] Observer's specified target Dec
# DEFOCUS =  1.4398718632593E-03 / [mm] SIM defocus
# RA_NOM  =  2.6641519201128E+02 / [deg] Nominal RA
# DEC_NOM = -2.9012248288366E+01 / [deg] Nominal Dec
# ROLL_NOM=  2.7674669390386E+02 / [deg] Nominal Roll
# COMMENT
# COMMENT AXAF FITS File ACIS specific keywords
# COMMENT
# READMODE= 'TIMED   '           / Read mode
# ACSYS1  = 'CHIP:AXAF-ACIS-1.0' / reference for chip coord system
# ACSYS2  = 'TDET:ACIS-2.2'      / reference for tiled detector coord system
# ACSYS3  = 'DET:ASC-FP-1.1'     / reference for focal plane coord system
# ACSYS4  = 'SKY:ASC-FP-1.1'     / reference for sky coord system
# GAINFILE= 'acisD2000-01-29gain_ctiN0006.fits'
# CTI_CORR=                    T
# CTI_APP = 'PPPPPBPBPP'
# CTIFILE = 'acisD2002-08-01ctiN0007.fits'
# MTLFILE = 'acisf05950_000N003_fptemp_egti1.fits'
# TGAINCOR= 'T       '
# TGAINFIL= 'acisD2005-05-01t_gainN0006.fits'
# GRD_FILE= 'acisD1996-11-01gradeN0004.fits'
# CORNERS =                    2 / num adjacent side pix > threshold to include co
# GRADESYS= 'ASCA    '           / grade system: ASCA, ACIS, or USER
# BPIXFILE= 'acisf05950_000N003_bpix1.fits'
# DATAMODE= 'FAINT   '           / Data mode
# RUN_ID  =                    1 / Science run index
# FSW_VERS=                   31 / ACIS flight software version number
# STARTBEP=            944432149 / BEP timer value at TSTART
# STOPBEP =           1588436149 / BEP timer value at TSTOP
# COMMENT
# COMMENT Product specific keywords are inserted here
# COMMENT
# FEP_ID  =                    1 / Front End Processor ID: 0-5
# CCD_ID  =                    3 / CCD ID: 0-9
# TIMEDELA=  3.1410400000000E+00 / Inferred duration of primary exposure (s)
# TIMEDELB=  0.0000000000000E+00 / Inferred duration of secondary exp. (s)
# FLSHTIME=  0.0000000000000E+00 / [s]
# EXPTIME =  3.1000000000000E+00 / [s]
# DTYCYCLE=                    0
# FIRSTROW=                    1 / Index of first row of CCD (sub)array readout
# NROWS   =                 1024 / Number of rows in (sub)array readout
# FLSHTIMA=  0.0000000000000E+00 / Inferred duration of flush before primary fram
# FLSHTIMB=  0.0000000000000E+00 / Inferred duration of flush before secondary fr
# CYCLE   = 'P       '           / events from which exps? Prim/Second/Both
# COMMENT
# COMMENT                        / Column format information block----------------
# COMMENT
# COMMENT
# COMMENT                        / History information block----------------------
# COMMENT
# HISTNUM =                  532
# HISTORY  TOOL  :ade                                                     ASC00001
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//TP_ADE____4ASC00002
# HISTORY  CONT  :72749395n633/input/acisf238621733N003_SR0.strip         ASC00003
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_sASC00004
# HISTORY  CONT  :trip_file_info.dat@@/main/2                             ASC00005
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_fASC00006
# HISTORY  CONT  :ile_info.dat@@/main/12                                  ASC00007
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_cASC00008
# HISTORY  CONT  :onfig_file.dat@@/main/2                                 ASC00009
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_gASC00010
# HISTORY  CONT  :roup_info.dat@@/main/12                                 ASC00011
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_dASC00012
# HISTORY  CONT  :p_info.dat@@/main/21                                    ASC00013
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_dASC00014
# HISTORY  CONT  :eahk_dp_info.dat@@/main/1                               ASC00015
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_cASC00016
# HISTORY  CONT  :ommon_dp_info.dat@@/main/9                              ASC00017
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/acis_cASC00018
# HISTORY  CONT  :al_info.dat@@/main/2                                    ASC00019
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# TITLE   = 'Simultaneous Gamma-Ray to Sub-Millimeter Monitoring of Sagittarius &'
# CONTINUE  'A*      '           / Proposal title
# OBSERVER= 'Dr. Frederick Baganoff' / Principal investigator
# OBJECT  = 'Sgr A*  '           / Source name
# OBS_ID  = '5950    '           / Observation id
# SEQ_NUM = '600469  '           / Sequence number
# HISTORY  TOOL  :acis_format_events   2012-12-26T16:26:16                ASC00020
# HISTORY  PARM  :infile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00021
# HISTORY  CONT  :472821934n007/input/acisf05950_000N003_evt0.lis         ASC00022
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00023
# ONTIME  =  4.9175299905419E+04 / [s] Sum of GTIs
# ONTIME3 =  4.9175299905419E+04 / [s] Sum of GTIs
# ONTIME2 =  4.9175299905419E+04 / [s] Sum of GTIs
# ONTIME1 =  4.9175299905419E+04 / [s] Sum of GTIs
# ONTIME0 =  4.9175299905419E+04 / [s] Sum of GTIs
# ONTIME6 =  4.9175299905419E+04 / [s] Sum of GTIs
# LIVETIME=  4.8532788409826E+04 / [s] Livetime
# LIVTIME3=  4.8532788409826E+04 / [s] Livetime
# LIVTIME2=  4.8532788409826E+04 / [s] Livetime
# LIVTIME1=  4.8532788409826E+04 / [s] Livetime
# LIVTIME0=  4.8532788409826E+04 / [s] Livetime
# LIVTIME6=  4.8532788409826E+04 / [s] Livetime
# EXPOSURE=  4.8532788409826E+04 / [s] Exposure time
# EXPOSUR3=  4.8532788409826E+04 / [s] Exposure time
# EXPOSUR2=  4.8532788409826E+04 / [s] Exposure time
# EXPOSUR1=  4.8532788409826E+04 / [s] Exposure time
# EXPOSUR0=  4.8532788409826E+04 / [s] Exposure time
# EXPOSUR6=  4.8532788409826E+04 / [s] Exposure time
# DTCOR   =  9.8693426381071E-01 / Dead time correction
# HISTORY  CONT  :4n007/input/acisf238623005N003_1_evt0.fits[time=23862230ASC00024
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00025
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00026
# HISTORY  CONT  :4n007/input/acisf238623005N003_2_evt0.fits[time=23862230ASC00027
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00028
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00029
# HISTORY  CONT  :4n007/input/acisf238623005N003_3_evt0.fits[time=23862230ASC00030
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00031
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00032
# HISTORY  CONT  :4n007/input/acisf238623005N003_4_evt0.fits[time=23862230ASC00033
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00034
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00035
# HISTORY  CONT  :4n007/input/acisf238623005N003_5_evt0.fits[time=23862230ASC00036
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00037
# HISTORY  PARM  :biasfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_LASC00038
# HISTORY  CONT  :1_472821934n007/input/acisf05950_000N003_bias0.lis      ASC00039
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00040
# HISTORY  CONT  :4n007/input/acisf238621834N003_1_bias0.fits             ASC00041
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00042
# HISTORY  CONT  :4n007/input/acisf238621834N003_2_bias0.fits             ASC00043
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00044
# HISTORY  CONT  :4n007/input/acisf238621834N003_3_bias0.fits             ASC00045
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00046
# HISTORY  CONT  :4n007/input/acisf238621834N003_4_bias0.fits             ASC00047
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00048
# HISTORY  CONT  :4n007/input/acisf238621834N003_5_bias0.fits             ASC00049
# HISTORY  PARM  :exrfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1ASC00050
# HISTORY  CONT  :_472821934n007/input/acisf05950_000N003_exr0.lis        ASC00051
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00052
# HISTORY  CONT  :4n007/input/acisf238623005N003_1_exr0.fits[time=23862230ASC00053
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00054
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00055
# HISTORY  CONT  :4n007/input/acisf238623005N003_2_exr0.fits[time=23862230ASC00056
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00057
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00058
# HISTORY  CONT  :4n007/input/acisf238623005N003_3_exr0.fits[time=23862230ASC00059
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00060
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00061
# HISTORY  CONT  :4n007/input/acisf238623005N003_4_exr0.fits[time=23862230ASC00062
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00063
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00064
# HISTORY  CONT  :4n007/input/acisf238623005N003_5_exr0.fits[time=23862230ASC00065
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00066
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00067
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_epr1.fits       ASC00068
# HISTORY  PARM  :outbias=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00069
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003                 ASC00070
# HISTORY  PARM  :expstatsfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_ASC00071
# HISTORY  CONT  :F_L1_472821934n007/output/acisf05950_000N003_stat1.fits ASC00072
# HISTORY  PARM  :obsfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00073
# HISTORY  CONT  :472821934n007/input/axaff05950_000N003_obs0a.par        ASC00074
# HISTORY  PARM  :logfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00075
# HISTORY  CONT  :472821934n007/output/acis_format_events.log             ASC00076
# HISTORY  PARM  :bias_correct=yes                                        ASC00077
# HISTORY  PARM  :oc_correct=yes                                          ASC00078
# HISTORY  PARM  :geompar=geom                                            ASC00079
# HISTORY  PARM  :eventdef={d:time,i:expno,s:chipx,s:chipy,s:phas,s:ccd_idASC00080
# HISTORY  CONT  :,s:node_id,x:status}                                    ASC00081
# HISTORY  PARM  :telev1={d:time,i:expno,s:chipx,s:chipy,s:phas,s:ccd_id,sASC00082
# HISTORY  CONT  ::node_id,x:status}                                      ASC00083
# HISTORY  PARM  :vflev1={d:time,i:expno,s:chipx,s:chipy,s:phas,s:ccd_id,sASC00084
# HISTORY  CONT  ::node_id,x:status}                                      ASC00085
# HISTORY  PARM  :cclev1={d:time,i:expno,s:chipx,s:chipy,s:phas,s:ccd_id,sASC00086
# HISTORY  CONT  ::node_id,x:status}                                      ASC00087
# HISTORY  PARM  :tegrflev1={d:time,i:expno,s:chipx,s:chipy,l:pha,s:fltgraASC00088
# HISTORY  CONT  :de,s:corn_pha,s:ccd_id,s:node_id,x:status}              ASC00089
# ASPTYPE = 'KALMAN  '
# HISTORY  PARM  :ccgrlev1={d:time,i:expno,s:chipx,s:chipy,l:pha,s:fltgradASC00090
# HISTORY  CONT  :e,s:corn_pha,s:ccd_id,s:node_id,x:status}               ASC00091
# HISTORY  PARM  :verbose=0                                               ASC00092
# HISTORY  PARM  :tempbias=no                                             ASC00093
# HISTORY  PARM  :clobber=no                                              ASC00094
# HISTORY  PARM  :PIXLIB Version: 4.0.0                                   ASC00095
# HISTORY  PARM  :******     PIXLIB Parameter File      *****             ASC00096
# HISTORY  PARM  :/dsops/repro4/sdp.1/opus/prs_run/tmp/ACIS_F_L1_472821934ASC00097
# HISTORY  CONT  :n007/output/param/geom.par:                             ASC00098
# HISTORY  PARM  :instruments  = /data/CALDB/sdp/data/chandra/default/geomASC00099
# HISTORY  CONT  :/telD1999-07-23geomN0006.fits(CALDB)                    ASC00100
# HISTORY  PARM  :aimpoints    = /data/CALDB/sdp/data/chandra/default/aimpASC00101
# HISTORY  CONT  :ts/telD1999-07-23aimptsN0002.fits(CALDB)                ASC00102
# HISTORY  PARM  :tdet         = /data/CALDB/sdp/data/chandra/default/tdetASC00103
# HISTORY  CONT  :/telD1999-07-23tdetN0001.fits(CALDB)                    ASC00104
# HISTORY  PARM  :sky          = /data/CALDB/sdp/data/chandra/default/sky/ASC00105
# HISTORY  CONT  :telD1999-07-23skyN0002.fits(CALDB)                      ASC00106
# HISTORY  PARM  :shell        = /data/CALDB/sdp/data/chandra/default/sgeoASC00107
# HISTORY  CONT  :m/telD1999-07-23sgeomN0001.fits(CALDB)                  ASC00108
# HISTORY  PARM  :obsfile      = 2005-07-24T19:58:27(/dsops/repro4/sdp.1/oASC00109
# HISTORY  CONT  :pus/prs_run/tmp//ACIS_F_L1_472821934n007/input/axaff0595ASC00110
# HISTORY  CONT  :0_000N003_obs0a.par)                                    ASC00111
# HISTORY  PARM  :******     PIXLIB System Configuration      ******      ASC00112
# HISTORY  PARM  :Telescope = axaf                                        ASC00113
# HISTORY  PARM  :Focal Length (mm) = 10070.000                           ASC00114
# HISTORY  PARM  :Detector = ACIS                                         ASC00115
# HISTORY  PARM  :Focal Plane Sys. = FP-1.1                               ASC00116
# HISTORY  PARM  :Tiled Detector Plane Sys. = ACIS-2.2                    ASC00117
# HISTORY  PARM  :SIM Offset (mm) = (0.684 0.75 236.552)                  ASC00118
# HISTORY  PARM  :Aim Point(AI1) (mm) = (-0.782348 0 -237.5)              ASC00119
# HISTORY  PARM  :Grating Arm = HEG                                       ASC00120
# HISTORY  PARM  :Grating Order =  1                                      ASC00121
# HISTORY  PARM  :Dispersion Plane Sys. = ASC-GDP-1.1                     ASC00122
# HISTORY  PARM  :Rowland Circle (mm) = 8632.48                           ASC00123
# BIASFIL3= 'acisf238621834N003_1_bias0.fits' / bias file used: CCD 3
# BIASFIL2= 'acisf238621834N003_2_bias0.fits' / bias file used: CCD 2
# BIASFIL1= 'acisf238621834N003_3_bias0.fits' / bias file used: CCD 1
# BIASFIL0= 'acisf238621834N003_4_bias0.fits' / bias file used: CCD 0
# BIASFIL6= 'acisf238621834N003_5_bias0.fits' / bias file used: CCD 6
# HISTORY  TOOL  :acis_sort_time   2012-12-26T16:27:18                    ASC00124
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00125
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_epr1.fits        ASC00126
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00127
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_tim1.fits       ASC00128
# HISTORY  PARM  :clobber=no                                              ASC00129
# HISTORY  PARM  :verbose=0                                               ASC00130
# HISTORY  TOOL  :destreak   2012-12-26T16:28:31                          ASC00131
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00132
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_tim1.fits        ASC00133
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00134
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_tmp_evt1.fits   ASC00135
# HISTORY  PARM  :max=                                                    ASC00136
# HISTORY  PARM  :max_rowloss_fraction=5e-05                              ASC00137
# HISTORY  PARM  :num_sigma=1                                             ASC00138
# HISTORY  PARM  :filter=no                                               ASC00139
# HISTORY  PARM  :mask=                                                   ASC00140
# HISTORY  PARM  :ccd_id=8                                                ASC00141
# HISTORY  PARM  :ccd_col=ccd_id                                          ASC00142
# HISTORY  PARM  :node_col=node_id                                        ASC00143
# HISTORY  PARM  :exptime=-1                                              ASC00144
# HISTORY  PARM  :countfile=                                              ASC00145
# HISTORY  PARM  :fracfile=                                               ASC00146
# HISTORY  PARM  :timefile=                                               ASC00147
# HISTORY  PARM  :verbose=0                                               ASC00148
# HISTORY  PARM  :clobber=no                                              ASC00149
# HISTORY  TOOL  :dmhedit   2012-12-26T16:29:08                           ASC00150
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00151
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_tmp_evt1.fits    ASC00152
# HISTORY  PARM  :filelist=                                               ASC00153
# HISTORY  PARM  :operation=add                                           ASC00154
# HISTORY  PARM  :key=CONTENT                                             ASC00155
# HISTORY  PARM  :value=EVT1                                              ASC00156
# HISTORY  PARM  :datatype=string                                         ASC00157
# HISTORY  PARM  :unit=                                                   ASC00158
# HISTORY  PARM  :comment=                                                ASC00159
# HISTORY  PARM  :verbose=0                                               ASC00160
# FP_TEMP =  1.5360722351000E+02 / [K] Focal Plane Temperature
# HISTORY  TOOL  :dmhedit   2012-12-26T16:32:39                           ASC00161
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00162
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_tmp_evt1.fits    ASC00163
# HISTORY  PARM  :filelist=                                               ASC00164
# HISTORY  PARM  :operation=add                                           ASC00165
# HISTORY  PARM  :key=FP_TEMP                                             ASC00166
# HISTORY  PARM  :value=153.60722351                                      ASC00167
# HISTORY  PARM  :datatype=double                                         ASC00168
# HISTORY  PARM  :unit=K                                                  ASC00169
# HISTORY  PARM  :comment=Focal Plane Temperature                         ASC00170
# HISTORY  PARM  :verbose=0                                               ASC00171
# HISTORY  TOOL  :acis_process_events   2012-12-26T16:33:33               ASC00172
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00173
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_tmp_evt1.fits    ASC00174
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00175
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_evt1.fits       ASC00176
# HISTORY  PARM  :acaofffile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_FASC00177
# HISTORY  CONT  :_L1_472821934n007/input/pcadf05950_000N003_asol1.lis    ASC00178
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00179
# HISTORY  CONT  :4n007/input/pcadf238623220N003_asol1.fits[time=238622307ASC00180
# HISTORY  CONT  :.9161900:238673270.9185200]                             ASC00181
# HISTORY  PARM  :apply_cti=yes                                           ASC00182
# HISTORY  PARM  :apply_tgain=yes                                         ASC00183
# HISTORY  PARM  :alignmentfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIASC00184
# HISTORY  CONT  :S_F_L1_472821934n007/input/pcadf05950_000N003_asol1.lis ASC00185
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00186
# HISTORY  CONT  :4n007/input/pcadf238623220N003_asol1.fits[time=238622307ASC00187
# HISTORY  CONT  :.9161900:238673270.9185200]                             ASC00188
# HISTORY  PARM  :obsfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00189
# HISTORY  CONT  :472821934n007/output/axaff05950_000N003_obs0a.par       ASC00190
# HISTORY  PARM  :geompar=geom                                            ASC00191
# HISTORY  PARM  :logfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00192
# HISTORY  CONT  :472821934n007/output/acis_process_events.log            ASC00193
# HISTORY  PARM  :gradefile=CALDB                                         ASC00194
# HISTORY  PARM  :grade_image_file=CALDB                                  ASC00195
# HISTORY  PARM  :gainfile=CALDB                                          ASC00196
# HISTORY  PARM  :badpixfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_ASC00197
# HISTORY  CONT  :L1_472821934n007/output/acisf05950_000N003_bpix1.fits   ASC00198
# HISTORY  PARM  :threshfile=CALDB                                        ASC00199
# HISTORY  PARM  :ctifile=CALDB                                           ASC00200
# HISTORY  PARM  :tgainfile=CALDB                                         ASC00201
# HISTORY  PARM  :mtlfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00202
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_fptemp_egti1.fitASC00203
# HISTORY  CONT  :s                                                       ASC00204
# HISTORY  PARM  :eventdef={d:time,s:ccd_id,s:node_id,i:expno,s:chip,s:tdeASC00205
# HISTORY  CONT  :t,f:det,f:sky,s:phas,l:pha,l:pha_ro,f:energy,l:pi,s:fltgASC00206
# HISTORY  CONT  :rade,s:grade,x:status}                                  ASC00207
# HISTORY  PARM  :doevtgrade=yes                                          ASC00208
# HISTORY  PARM  :check_vf_pha=no                                         ASC00209
# HISTORY  PARM  :calc_cc_times=yes                                       ASC00210
# HISTORY  PARM  :trail=0.027                                             ASC00211
# HISTORY  PARM  :spthresh=13                                             ASC00212
# HISTORY  PARM  :time_offset=0                                           ASC00213
# HISTORY  PARM  :calculate_pi=yes                                        ASC00214
# HISTORY  PARM  :pi_bin_width=14.6                                       ASC00215
# HISTORY  PARM  :pi_num_bins=1024                                        ASC00216
# HISTORY  PARM  :max_cti_iter=15                                         ASC00217
# HISTORY  PARM  :cti_converge=0.1                                        ASC00218
# HISTORY  PARM  :tstart=TSTART                                           ASC00219
# HISTORY  PARM  :tstop=TSTOP                                             ASC00220
# HISTORY  PARM  :clobber=no                                              ASC00221
# HISTORY  PARM  :verbose=0                                               ASC00222
# HISTORY  PARM  :stop=sky                                                ASC00223
# HISTORY  PARM  :instrume=acis                                           ASC00224
# HISTORY  PARM  :rand_seed=1                                             ASC00225
# HISTORY  PARM  :rand_pha=yes                                            ASC00226
# HISTORY  PARM  :pix_adj=EDSER                                           ASC00227
# HISTORY  PARM  :subpixfile=CALDB                                        ASC00228
# HISTORY  PARM  :stdlev1={d:time,s:ccd_id,s:node_id,i:expno,s:chip,s:tdetASC00229
# HISTORY  CONT  :,f:det,f:sky,s:phas,l:pha,l:pha_ro,f:energy,l:pi,s:fltgrASC00230
# HISTORY  CONT  :ade,s:grade,x:status}                                   ASC00231
# HISTORY  PARM  :grdlev1={d:time,s:ccd_id,s:node_id,i:expno,s:chip,s:tdetASC00232
# HISTORY  CONT  :,f:det,f:sky,l:pha,l:pha_ro,s:corn_pha,f:energy,l:pi,s:fASC00233
# HISTORY  CONT  :ltgrade,s:grade,x:status}                               ASC00234
# HISTORY  PARM  :cclev1={d:time,d:time_ro,s:ccd_id,s:node_id,i:expno,s:chASC00235
# HISTORY  CONT  :ip,s:tdet,f:det,f:sky,f:sky_1d,s:phas,l:pha,l:pha_ro,f:eASC00236
# HISTORY  CONT  :nergy,l:pi,s:fltgrade,s:grade,x:status}                 ASC00237
# HISTORY  PARM  :ccgrdlev1={d:time,d:time_ro,s:ccd_id,s:node_id,i:expno,sASC00238
# HISTORY  CONT  ::chip,s:tdet,f:det,f:sky,f:sky_1d,l:pha,l:pha_ro,s:corn_ASC00239
# HISTORY  CONT  :pha,f:energy,l:pi,s:fltgrade,s:grade,x:status}          ASC00240
# HISTORY  PARM  :PIXLIB Version: 4.0.0                                   ASC00241
# HISTORY  PARM  :******     PIXLIB Parameter File      *****             ASC00242
# HISTORY  PARM  :/dsops/repro4/sdp.1/opus/prs_run/tmp/ACIS_F_L1_472821934ASC00243
# HISTORY  CONT  :n007/output/param/geom.par:                             ASC00244
# HISTORY  PARM  :instruments  = /data/CALDB/sdp/data/chandra/default/geomASC00245
# HISTORY  CONT  :/telD1999-07-23geomN0006.fits(CALDB)                    ASC00246
# HISTORY  PARM  :aimpoints    = /data/CALDB/sdp/data/chandra/default/aimpASC00247
# HISTORY  CONT  :ts/telD1999-07-23aimptsN0002.fits(CALDB)                ASC00248
# HISTORY  PARM  :tdet         = /data/CALDB/sdp/data/chandra/default/tdetASC00249
# HISTORY  CONT  :/telD1999-07-23tdetN0001.fits(CALDB)                    ASC00250
# HISTORY  PARM  :sky          = /data/CALDB/sdp/data/chandra/default/sky/ASC00251
# HISTORY  CONT  :telD1999-07-23skyN0002.fits(CALDB)                      ASC00252
# HISTORY  PARM  :shell        = /data/CALDB/sdp/data/chandra/default/sgeoASC00253
# HISTORY  CONT  :m/telD1999-07-23sgeomN0001.fits(CALDB)                  ASC00254
# HISTORY  PARM  :obsfile      = 2005-07-24T19:58:27(/dsops/repro4/sdp.1/oASC00255
# HISTORY  CONT  :pus/prs_run/tmp//ACIS_F_L1_472821934n007/input/axaff0595ASC00256
# HISTORY  CONT  :0_000N003_obs0a.par)                                    ASC00257
# HISTORY  PARM  :******     PIXLIB System Configuration      ******      ASC00258
# HISTORY  PARM  :Telescope = FLIGHT                                      ASC00259
# HISTORY  PARM  :Focal Length (mm) = 10070.000                           ASC00260
# HISTORY  PARM  :Detector = ACIS                                         ASC00261
# HISTORY  PARM  :Focal Plane Sys. = FP-1.1                               ASC00262
# HISTORY  PARM  :Tiled Detector Plane Sys. = ACIS-2.2                    ASC00263
# HISTORY  PARM  :SIM Offset (mm) = (0.684 0.75 236.552)                  ASC00264
# HISTORY  PARM  :Aim Point(NONE) (mm) = (-0.780908 0 -233.587)           ASC00265
# HISTORY  PARM  :Grating Arm = HEG                                       ASC00266
# HISTORY  PARM  :Grating Order =  1                                      ASC00267
# HISTORY  PARM  :Dispersion Plane Sys. = ASC-GDP-1.1                     ASC00268
# HISTORY  PARM  :Rowland Circle (mm) = 8632.48                           ASC00269
# HISTORY  PARM  :Stage Ang (arc-mins) = (0 0 0)                          ASC00270
# HISTORY  PARM  :Stage Pos (mm) = (0 0 0)                                ASC00271
# HISTORY  PARM  :Pitch-Yaw (arc-mins) = (0 0           )                 ASC00272
# HISTORY  TOOL  :acis_build_chip_gti   2012-12-26T16:50:58               ASC00273
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00274
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_stat1.fits       ASC00275
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_ASC00276
# HISTORY  CONT  :472821934n007/output/acisf05950_000N003_evt1.fits       ASC00277
# HISTORY  PARM  :pbkfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1ASC00278
# HISTORY  CONT  :_472821934n007/input/acisf05950_000N003_pbk0.lis        ASC00279
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00280
# HISTORY  CONT  :4n007/input/acisf238623005N003_pbk0.fits[time=238622307.ASC00281
# HISTORY  CONT  :9161900:238673270.9185200]                              ASC00282
# HISTORY  PARM  :exrfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1ASC00283
# HISTORY  CONT  :_472821934n007/input/acisf05950_000N003_exr0.lis        ASC00284
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00285
# HISTORY  CONT  :4n007/input/acisf238623005N003_1_exr0.fits[time=23862230ASC00286
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00287
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00288
# HISTORY  CONT  :4n007/input/acisf238623005N003_2_exr0.fits[time=23862230ASC00289
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00290
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00291
# HISTORY  CONT  :4n007/input/acisf238623005N003_3_exr0.fits[time=23862230ASC00292
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00293
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00294
# HISTORY  CONT  :4n007/input/acisf238623005N003_4_exr0.fits[time=23862230ASC00295
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00296
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00297
# HISTORY  CONT  :4n007/input/acisf238623005N003_5_exr0.fits[time=23862230ASC00298
# HISTORY  CONT  :7.9161900:238673270.9185200]                            ASC00299
# HISTORY  PARM  :aspfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1ASC00300
# HISTORY  CONT  :_472821934n007/input/pcadf05950_000N003_asol1.lis       ASC00301
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_47282193ASC00302
# HISTORY  CONT  :4n007/input/pcadf238623220N003_asol1.fits[time=238622307ASC00303
# HISTORY  CONT  :.9161900:238673270.9185200]                             ASC00304
# HISTORY  PARM  :geompar=geom                                            ASC00305
# HISTORY  PARM  :nominalchip=3                                           ASC00306
# HISTORY  PARM  :verbose=0                                               ASC00307
# HISTORY  TOOL  :dmhedit   2012-12-26T16:59:17                           ASC00308
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00309
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_evt1.fits[EVENTS]ASC00310
# HISTORY  CONT  :,/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4728219ASC00311
# HISTORY  CONT  :34n007/output/acisf05950_000N003_aoff1.fits[ASPOFF],/dsoASC00312
# HISTORY  CONT  :ps/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_472821934n00ASC00313
# HISTORY  CONT  :7/output/acisf05950_000N003_soff1.fits[ALIGN],/dsops/repASC00314
# HISTORY  CONT  :ro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_472821934n007/outpASC00315
# HISTORY  CONT  :ut/acisf05950_000N003_std_flt1.fits[FILTER],/dsops/reproASC00316
# HISTORY  CONT  :4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_472821934n007/outputASC00317
# HISTORY  CONT  :/acisf05950_000N003_flt1.fits[FILTER],/dsops/repro4/sdp.ASC00318
# HISTORY  CONT  :1/opus/prs_run/tmp//ACIS_F_L1_472821934n007/output/acisfASC00319
# HISTORY  CONT  :05950_000N003_bpix1.fits[2],/dsops/repro4/sdp.1/opus/prsASC00320
# HISTORY  CONT  :_run/tmp//ACIS_F_L1_472821934n007/output/acisf05950_000NASC00321
# HISTORY  CONT  :003_msk1.fits[2]                                        ASC00322
# HISTORY  PARM  :filelist=                                               ASC00323
# HISTORY  PARM  :operation=add                                           ASC00324
# HISTORY  PARM  :key=REVISION                                            ASC00325
# HISTORY  PARM  :value=3                                                 ASC00326
# HISTORY  PARM  :datatype=long                                           ASC00327
# ...
# DY_AVG  =  3.6659877247000E-01 / [mm] Mean DY during observation
# DZ_AVG  =  5.0086867058000E-01 / [mm] Mean DZ during observation
# DTH_AVG = -1.9774300569000E-03 / [deg] Mean DTHETA during observation
# HISTORY  TOOL  :dmhedit   2012-12-26T17:00:41                           ASC00422
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00423
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_evt1.fits[EVENTS]ASC00424
# HISTORY  CONT  :[events]                                                ASC00425
# HISTORY  PARM  :filelist=.//12164.hdr                                   ASC00426
# HISTORY  PARM  :operation=add                                           ASC00427
# HISTORY  PARM  :key=BPIXFILE                                            ASC00428
# HISTORY  PARM  :value=acisD2000-11-28badpixN0003.fits                   ASC00429
# HISTORY  PARM  :datatype=indef                                          ASC00430
# HISTORY  PARM  :unit=                                                   ASC00431
# HISTORY  PARM  :comment=                                                ASC00432
# HISTORY  PARM  :verbose=0                                               ASC00433
# OCLKPAIR=                    8 / # of pairs of overclock pixels per output
# ORC_MODE=                    0 / Output register clocking mode
# SUM_2X2 =                    0 / On-chip summing. 0:None; 1:Sum 2x2
# HISTORY  TOOL  :dmhedit   2012-12-26T17:00:55                           ASC00434
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00435
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_evt1.fits[EVENTS]ASC00436
# HISTORY  CONT  :[events]                                                ASC00437
# HISTORY  PARM  :filelist=.//12535.hdr                                   ASC00438
# HISTORY  PARM  :operation=add                                           ASC00439
# HISTORY  PARM  :key=BPIXFILE                                            ASC00440
# HISTORY  PARM  :value=acisD2000-11-28badpixN0003.fits                   ASC00441
# HISTORY  PARM  :datatype=indef                                          ASC00442
# HISTORY  PARM  :unit=                                                   ASC00443
# HISTORY  PARM  :comment=                                                ASC00444
# HISTORY  PARM  :verbose=0                                               ASC00445
# FEP_CCD = 'x32106  '           / CCD to FEPID mapping, fep0 is left most digit
# HISTORY  TOOL  :dmhedit   2012-12-26T17:01:00                           ASC00446
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00447
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_evt1.fits[EVENTS]ASC00448
# HISTORY  CONT  :[events]                                                ASC00449
# HISTORY  PARM  :filelist=                                               ASC00450
# HISTORY  PARM  :operation=add                                           ASC00451
# HISTORY  PARM  :key=FEP_CCD                                             ASC00452
# HISTORY  PARM  :value=x32106                                            ASC00453
# HISTORY  PARM  :datatype=string                                         ASC00454
# HISTORY  PARM  :unit=                                                   ASC00455
# HISTORY  PARM  :comment=CCD to FEPID mapping, fep0 is left most digit   ASC00456
# HISTORY  PARM  :verbose=0                                               ASC00457
# CALDBVER= '4.5.5   '
# HISTORY  TOOL  :dmhedit   2012-12-26T17:01:06                           ASC00458
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_4ASC00459
# HISTORY  CONT  :72821934n007/output/acisf05950_000N003_evt1.fits,/dsops/ASC00460
# HISTORY  CONT  :repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1_472821934n007/oASC00461
# HISTORY  CONT  :utput/acisf05950_000N003_bpix1.fits,/dsops/repro4/sdp.1/ASC00462
# HISTORY  CONT  :opus/prs_run/tmp//ACIS_F_L1_472821934n007/output/acisf05ASC00463
# HISTORY  CONT  :950_000N003_mtl1.fits,/dsops/repro4/sdp.1/opus/prs_run/tASC00464
# HISTORY  CONT  :mp//ACIS_F_L1_472821934n007/output/acisf05950_000N003_mtASC00465
# HISTORY  CONT  :l1.fits[MTL_S],/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIASC00466
# HISTORY  CONT  :S_F_L1_472821934n007/output/acisf05950_000N003_mtl1.fitsASC00467
# HISTORY  CONT  :[LIMITS],/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_F_L1ASC00468
# HISTORY  CONT  :_472821934n007/output/acisf05950_000N003_fov1.fits[FOV] ASC00469
# HISTORY  PARM  :filelist=                                               ASC00470
# HISTORY  PARM  :operation=add                                           ASC00471
# HISTORY  PARM  :key=CALDBVER                                            ASC00472
# HISTORY  PARM  :value=' 4.5.5    '                                      ASC00473
# HISTORY  PARM  :datatype=string                                         ASC00474
# HISTORY  PARM  :unit=                                                   ASC00475
# HISTORY  PARM  :comment=                                                ASC00476
# HISTORY  PARM  :verbose=0                                               ASC00477
# HISTORY  TOOL  :dmmerge   2012-12-26T17:20:03                           ASC00478
# HISTORY  PARM  :infile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___ASC00479
# HISTORY  CONT  :472824830n147/output/acisf05950N003_evt1.lis[cols !PHAS,ASC00480
# HISTORY  CONT  :!CORN_PHA]                                              ASC00481
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___47282483ASC00482
# HISTORY  CONT  :0n147/input/acisf05950_000N003_evt1.fits[@/dsops/repro4/ASC00483
# HISTORY  CONT  :sdp.1/opus/prs_run/tmp//ACIS_L2___472824830n147/input/acASC00484
# HISTORY  CONT  :isf05950_000N003_flt1.fits[subspace -expno]][subspace -eASC00485
# HISTORY  CONT  :xpno][cols !PHAS,!CORN_PHA]                             ASC00486
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___ASC00487
# HISTORY  CONT  :472824830n147/output/tmp_acisf05950N003_evt2.fits       ASC00488
# HISTORY  PARM  :outBlock=                                               ASC00489
# HISTORY  PARM  :lookupTab=/home/ascds/DS.rap/data/lev2_dmmerge_lookup.txASC00490
# HISTORY  CONT  :t                                                       ASC00491
# HISTORY  PARM  :columnList=                                             ASC00492
# HISTORY  PARM  :clobber=no                                              ASC00493
# HISTORY  PARM  :verbose=0                                               ASC00494
# MTYPE1  = 'chip    '           / DM Keyword: Descriptor name.
# MFORM1  = 'chipx,chipy'        / [pixel]
# MTYPE2  = 'tdet    '           / DM Keyword: Descriptor name.
# MFORM2  = 'tdetx,tdety'        / [pixel]
# MTYPE3  = 'det     '           / DM Keyword: Descriptor name.
# MFORM3  = 'detx,dety'          / [pixel]
# MTYPE4  = 'sky     '           / DM Keyword: Descriptor name.
# MFORM4  = 'x,y     '           / [pixel]
# DSTYP1  = 'time    '           / DM Keyword: Descriptor name.
# DSVAL1  = 'TABLE   '           / [s]
# DSFORM1 = 'D       '           / DM Keyword: Descriptor datatype.
# DSUNIT1 = 's       '           / DM Keyword: Descriptor unit.
# DSREF1  = ':GTI3   '
# 2DSREF1 = ':GTI2   '
# 3DSREF1 = ':GTI1   '
# 4DSREF1 = ':GTI0   '
# 5DSREF1 = ':GTI6   '
# DSTYP2  = 'ccd_id  '           / DM Keyword: Descriptor name.
# DSVAL2  = '3:3     '           / DM Keyword: Descriptor value.
# DSFORM2 = 'I       '           / DM Keyword: Descriptor datatype.
# 2DSVAL2 = '2:2     '           /
# 3DSVAL2 = '1:1     '           /
# 4DSVAL2 = '0:0     '           /
# 5DSVAL2 = '6:6     '           /
# DSTYP3  = 'grade   '           / DM Keyword: Descriptor name.
# DSVAL3  = '0:0,2:2,3:3,4:4,6:6' / DM Keyword: Descriptor value.
# DSFORM3 = 'I       '           / DM Keyword: Descriptor datatype.
# 2DSVAL3 = '0:0,2:2,3:3,4:4,6:6' /
# 3DSVAL3 = '0:0,2:2,3:3,4:4,6:6' /
# 4DSVAL3 = '0:0,2:2,3:3,4:4,6:6' /
# 5DSVAL3 = '0:0,2:2,3:3,4:4,6:6' /
# DSTYP4  = 'phas    '           / DM Keyword: Descriptor name.
# DSVAL4  = '-4096:4095'         / DM Keyword: Descriptor value.
# DSFORM4 = 'I       '           / DM Keyword: Descriptor datatype.
# 2DSVAL4 = '-4096:4095'         /
# 3DSVAL4 = '-4096:4095'         /
# 4DSVAL4 = '-4096:4095'         /
# 5DSVAL4 = '-4096:4095'         /
# MTYPE5  = 'CPC     '           / DM Keyword: Descriptor name.
# MFORM5  = 'CPCX,CPCY'          / [mm]
# TCTYP5  = 'CPCX    '
# TCRVL5  =  0.0000000000000E+00
# TCRPX5  =  5.0000000000000E-01
# TCDLT5  =  2.3987000000000E-02
# TCUNI5  = 'mm      '
# TCTYP6  = 'CPCY    '
# TCRVL6  =  0.0000000000000E+00
# TCRPX6  =  5.0000000000000E-01
# TCDLT6  =  2.3987000000000E-02
# TCUNI6  = 'mm      '
# MTYPE6  = 'MSC     '           / DM Keyword: Descriptor name.
# MFORM6  = 'PHI,THETA'          / [deg]
# TCTYP9  = 'LONG-TAN'
# TCRVL9  =  0.0000000000000E+00
# TCRPX9  =  4.0965000000000E+03
# TCDLT9  =  1.3666666666667E-04
# TCNA9   = 'PHI     '
# TCUNI9  = 'deg     '
# LONP9   =  2.7000000000000E+02
# LATP9   =  9.0000000000000E+01
# TCTYP10 = 'NPOL-TAN'
# TCRVL10 =  0.0000000000000E+00
# TCRPX10 =  4.0965000000000E+03
# TCDLT10 =  1.3666666666667E-04
# TCNA10  = 'THETA   '
# TCUNI10 = 'deg     '
# MTYPE7  = 'EQPOS   '           / DM Keyword: Descriptor name.
# MFORM7  = 'RA,DEC  '           / [deg]
# TCTYP11 = 'RA---TAN'
# TCRVL11 =  2.6641519201128E+02
# TCRPX11 =  4.0965000000000E+03
# TCDLT11 = -1.3666666666667E-04
# TCUNI11 = 'deg     '
# TCTYP12 = 'DEC--TAN'
# TCRVL12 = -2.9012248288366E+01
# TCRPX12 =  4.0965000000000E+03
# TCDLT12 =  1.3666666666667E-04
# TCUNI12 = 'deg     '
# HISTORY  TOOL  :dmcopy   2012-12-26T17:20:21                            ASC00495
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___4ASC00496
# HISTORY  CONT  :72824830n147/output/tmp_acisf05950N003_evt2.fits[status=ASC00497
# HISTORY  CONT  :0,grade=0,2,3,4,6]                                      ASC00498
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___ASC00499
# HISTORY  CONT  :472824830n147/output/acisf05950N003_evt2.fits           ASC00500
# HISTORY  PARM  :kernel=default                                          ASC00501
# HISTORY  PARM  :option=                                                 ASC00502
# HISTORY  PARM  :verbose=0                                               ASC00503
# HISTORY  PARM  :clobber=no                                              ASC00504
# HISTORY  TOOL  :dmhedit   2012-12-26T17:20:44                           ASC00505
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___4ASC00506
# HISTORY  CONT  :72824830n147/output/acisf05950N003_evt2.fits[EVENTS]    ASC00507
# HISTORY  PARM  :filelist=                                               ASC00508
# HISTORY  PARM  :operation=add                                           ASC00509
# HISTORY  PARM  :key=HDUCLAS2                                            ASC00510
# HISTORY  PARM  :value=ACCEPTED                                          ASC00511
# HISTORY  PARM  :datatype=string                                         ASC00512
# HISTORY  PARM  :unit=                                                   ASC00513
# HISTORY  PARM  :comment=                                                ASC00514
# HISTORY  PARM  :verbose=0                                               ASC00515
# HISTORY  TOOL  :dmhedit   2012-12-26T17:20:49                           ASC00516
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___4ASC00517
# HISTORY  CONT  :72824830n147/output/acisf05950N003_evt2.fits[EVENTS],/dsASC00518
# HISTORY  CONT  :ops/repro4/sdp.1/opus/prs_run/tmp//ACIS_L2___472824830n1ASC00519
# HISTORY  CONT  :47/output/acisf05950N003_full_img2.fits[1],/dsops/repro4ASC00520
# HISTORY  CONT  :/sdp.1/opus/prs_run/tmp//ACIS_L2___472824830n147/output/ASC00521
# HISTORY  CONT  :acisf05950N003_cntr_img2.fits[1],/dsops/repro4/sdp.1/opuASC00522
# HISTORY  CONT  :s/prs_run/tmp//ACIS_L2___472824830n147/output/acisf05950ASC00523
# HISTORY  CONT  :N003_fov2.fits[FOV]                                     ASC00524
# HISTORY  PARM  :filelist=                                               ASC00525
# HISTORY  PARM  :operation=add                                           ASC00526
# HISTORY  PARM  :key=REVISION                                            ASC00527
# HISTORY  PARM  :value=3                                                 ASC00528
# HISTORY  PARM  :datatype=long                                           ASC00529
# HISTORY  PARM  :unit=                                                   ASC00530
# HISTORY  PARM  :comment=                                                ASC00531
# HISTORY  PARM  :verbose=0                                               ASC00532

# %% [markdown]
# For example, a preview of the table is easily viewed by simply running a cell with the table as the last line:

# %%
evt_data

# %% [markdown]
# We can extract data from the table by referencing the column name. Let's try making a histogram for the energy of each photon, which will give us a sense for the spectrum (folded with the detector's efficiency).

# %%
energy_hist = plt.hist(evt_data['energy'], bins='auto')

# %%
ii = np.in1d(evt_data['ccd_id'], [0, 1, 2, 3])
np.sum(ii)

# %% [markdown]
# ## Making a 2D histogram with some table data

# %% [markdown]
# ### Method 1: Use numpy to make a 2D histogram and imshow to display it

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

NBINS = (100,100)

img_zero, yedges, xedges = np.histogram2d(evt_data['x'][ii], evt_data['y'][ii], NBINS)

extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.imshow(img_zero, extent=extent, interpolation='nearest', cmap='gist_yarg', origin='lower')

plt.xlabel('x', fontsize = axis_label_fs)
plt.ylabel('y', fontsize = axis_label_fs)

# Adjust axis labels and ticks for the main plot
ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
ax.tick_params(which='minor', length=4)

# To see more color maps
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %% [markdown]
# ### Method 2: Use hist2d with a log-normal color scheme

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

NBINS = (100,100)
img_zero_mpl = plt.hist2d(evt_data['x'][ii], evt_data['y'][ii], NBINS, 
                          cmap='viridis', norm=LogNorm())

cbar = plt.colorbar(ticks=[1.0,3.0,6.0])
cbar.ax.set_yticklabels(['1','3','6'])

plt.xlabel('x', fontsize = axis_label_fs)
plt.ylabel('y', fontsize = axis_label_fs)

# Adjust axis labels and ticks for the main plot
ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
ax.tick_params(which='minor', length=4)

# Adjust axis labels and ticks for the colorbar
cbar.ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
cbar.ax.tick_params(which='minor', length=4)

# %%
hdu_list.close()

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### #1: Make a scatter plot of the same data you histogrammed above. The plt.scatter function is your friend for this. What are the pros and cons of doing it this way?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

# Scatter plot using 'energy' for color mapping (or any other suitable variable)
scatter = plt.scatter(evt_data['x'][ii], evt_data['y'][ii], 
                      c=evt_data['energy'][ii], cmap='viridis', alpha=0.5)

# Create colorbar with specific ticks and labels
cbar = plt.colorbar(scatter, ax=ax, ticks=[1.0, 3.0, 6.0])  # Adjust ticks as needed
cbar.ax.set_yticklabels(['1', '3', '6'])  # Set labels for colorbar ticks

# Set axis labels
plt.xlabel('x', fontsize=axis_label_fs)
plt.ylabel('y', fontsize=axis_label_fs)

# Adjust axis labels and ticks for the main plot
ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
ax.tick_params(which='minor', length=4)

# Adjust axis labels and ticks for the colorbar
cbar.ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
cbar.ax.tick_params(which='minor', length=4)

plt.show()

# %% [markdown]
# ### #2: Try the same with the plt.hexbin plotting function. Which do you think looks better for this kind of data?

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

# Hexbin plot
hb = ax.hexbin(evt_data['x'][ii], evt_data['y'][ii], 
                gridsize=50, cmap='viridis', norm=LogNorm())

# Create colorbar with specific ticks and labels
cbar = plt.colorbar(hb, ax=ax, ticks=[1.0, 3.0, 6.0])  # Adjust ticks as needed
cbar.ax.set_yticklabels(['1', '3', '6'])  # Set labels for colorbar ticks

# Set axis labels
plt.xlabel('x', fontsize=axis_label_fs)
plt.ylabel('y', fontsize=axis_label_fs)

# Adjust axis labels and ticks for the main plot
ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
ax.tick_params(which='minor', length=4)

# Adjust axis labels and ticks for the colorbar
cbar.ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
cbar.ax.tick_params(which='minor', length=4)

plt.show()

# %% [markdown]
# ### #3: Choose an energy range to make a slice of the FITS table, then plot it. How does the image change with different energy ranges?

# %%
# Define energy ranges to analyze
energy_ranges = [
    (0, 2),   # Low energy range
    (2, 4),   # Medium energy range
    (4, 6)    # High energy range
]

# Create a figure for subplots
fig, axs = plt.subplots(1, len(energy_ranges), figsize=(15, 5))

for i, (low, high) in enumerate(energy_ranges):
    # Filter data based on energy range
    mask = (evt_data['energy'] >= low) & (evt_data['energy'] < high)
    
    # Hexbin plot for the selected energy range
    hb = axs[i].hexbin(evt_data['x'][mask], evt_data['y'][mask], 
                        gridsize=50, cmap='viridis', norm=LogNorm())
    
    # Set axis labels
    axs[i].set_xlabel('x', fontsize=axis_label_fs)
    axs[i].set_ylabel('y', fontsize=axis_label_fs)
    axs[i].set_title(f'Energy Range: {low} - {high}', fontsize=axis_label_fs)

    # Create colorbar for each subplot
    cbar = plt.colorbar(hb, ax=axs[i], ticks=[1.0, 3.0, 6.0])  # Adjust ticks as needed
    cbar.ax.set_yticklabels(['1', '3', '6'])  # Set labels for colorbar ticks
    cbar.ax.tick_params(labelsize=axis_num_fs, which='major', length=7)
    cbar.ax.tick_params(which='minor', length=4)

    # Adjust axis ticks
    axs[i].tick_params(labelsize=axis_num_fs, which='major', length=7)
    axs[i].tick_params(which='minor', length=4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Close the file

# %%
hdu_list.close()
