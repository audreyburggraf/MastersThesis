# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/constants.py"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %% [markdown]
# # Load in data

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND4_nterms2/load_band4_data_nterms2.py"

path = band4_nterms2_data_folder_path

ratios = np.load(os.path.join(path, "GaussianUniformRatios_best.npy"))


VectorsActual = np.load(os.path.join(path, "vector_data_actual_cartesian.npy"))


VectorsGaussian = np.load(os.path.join(path, "vector_data_gaussian_best.npy"))


params = pd.read_csv(os.path.join(path, "best_gaussian_params.csv"))


B4 = {
    'StokesI_wcs' : StokesI_wcs, 
    'ratios' : ratios,
    'xmin' : xmin,
    'xmax' : xmax,
    'ymin' : ymin,
    'ymax' : ymax, 
    'reference_length_pix' : reference_length_pix,
    'reference_length_AU' : reference_length_AU,
    'BMAJ_pix' : BMAJ_pix, 
    'BMIN_pix' : BMIN_pix, 
    'BPA_deg_cartesian' : BPA_deg_cartesian,
    'max_length_pix' : max_length_pix,
    'reference_fraction' : reference_fraction,
    'phi': params["phi"].iloc[0],
    'BMAJ': params["BMAJ"].iloc[0],
    'BMIN': params["BMIN"].iloc[0],
    'chi2': params["chi2"].iloc[0],
    'VectorsActual': VectorsActual, 
    'VectorsGaussian': VectorsGaussian,
    'POLI_mJy': POLI_debiased_mJy,
    'nx': nx,
    'ny': ny,
    'RA_centre_pix': RA_centre_pix,
    'Dec_centre_pix': Dec_centre_pix,
}
# Out:
# band = Band 4 nterms2
# max_str = 'J163135.750-240128.700'
# StokesI_wcs CRPIX = [513. 513.]
# StokesI_wcs CDELT = [-5.e-06  5.e-06]
# Pixel scale = 0.018 arcsec/pixel
# Dec_max_pix = 581
#
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND5/load_band5_data.py"

# path = band5_data_folder_path

# ratios = np.load(os.path.join(path, "GaussianUniformRatios_best.npy"))


# VectorsActual = np.load(os.path.join(path, "vector_data_actual_cartesian.npy"))


# VectorsGaussian = np.load(os.path.join(path, "vector_data_gaussian_best.npy"))


# params = pd.read_csv(os.path.join(path, "best_gaussian_params.csv"))


# B5 = {
#     'StokesI_wcs' : StokesI_wcs, 
#     'ratios' : ratios,
#     'xmin' : xmin,
#     'xmax' : xmax,
#     'ymin' : ymin,
#     'ymax' : ymax, 
#     'reference_length_pix' : reference_length_pix,
#     'reference_length_AU' : reference_length_AU,
#     'BMAJ_pix' : BMAJ_pix, 
#     'BMIN_pix' : BMIN_pix, 
#     'BPA_deg_cartesian' : BPA_deg_cartesian,
#     'max_length_pix' : max_length_pix,
#     'reference_fraction' : reference_fraction,
#     'phi': params["phi"].iloc[0],
#     'BMAJ': params["BMAJ"].iloc[0],
#     'BMIN': params["BMIN"].iloc[0],
#     'chi2': params["chi2"].iloc[0],
#     'VectorsActual': VectorsActual, 
#     'VectorsGaussian': VectorsGaussian,
#     'POLI_mJy': POLI_debiased_mJy,
#     'nx': nx,
#     'ny': ny,
#     'RA_centre_pix': RA_centre_pix,
#     'Dec_centre_pix': Dec_centre_pix,    
# }

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND5_robust_minus1/load_band5_robust_minus1_data.py"

path = band5_robust_minus1_data_folder_path

ratios = np.load(os.path.join(path, "GaussianUniformRatios_best.npy"))


VectorsActual = np.load(os.path.join(path, "vector_data_actual_cartesian.npy"))


VectorsGaussian = np.load(os.path.join(path, "vector_data_gaussian_best.npy"))


params = pd.read_csv(os.path.join(path, "best_gaussian_params.csv"))


B5_R1 = {
    'StokesI_wcs' : StokesI_wcs, 
    'ratios' : ratios,
    'xmin' : xmin,
    'xmax' : xmax,
    'ymin' : ymin,
    'ymax' : ymax, 
    'reference_length_pix' : reference_length_pix,
    'reference_length_AU' : reference_length_AU,
    'BMAJ_pix' : BMAJ_pix, 
    'BMIN_pix' : BMIN_pix, 
    'BPA_deg_cartesian' : BPA_deg_cartesian,
    'max_length_pix' : max_length_pix,
    'reference_fraction' : reference_fraction,
    'phi': params["phi"].iloc[0],
    'BMAJ': params["BMAJ"].iloc[0],
    'BMIN': params["BMIN"].iloc[0],
    'chi2': params["chi2"].iloc[0],
    'VectorsActual': VectorsActual, 
    'VectorsGaussian': VectorsGaussian,
    'POLI_mJy': POLI_debiased_mJy,
    'nx': nx,
    'ny': ny,
    'RA_centre_pix': RA_centre_pix,
    'Dec_centre_pix': Dec_centre_pix,    
}
# Out:
# band = Band 5 robust -1
# max_str = 'J163135.750-240128.700'
# StokesI_wcs CRPIX = [513. 513.]
# StokesI_wcs CDELT = [-5.e-06  5.e-06]
# Pixel scale = 0.018 arcsec/pixel
# Dec_max_pix = 581
#
# In make_vectors: the POLI_err_cutoff is 2.4
# In make_vectors: the POLI_err_cutoff is 2.4
# In make_vectors: the POLI_err_cutoff is 2.4
# In make_vectors: the POLI_err_cutoff is 2.4
# In make_vectors: the POLI_err_cutoff is 2.4
# In make_vectors: the POLI_err_cutoff is 2.4

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND6/load_band6_data.py"


path = band6_data_folder_path

ratios = np.load(os.path.join(path, "GaussianUniformRatios_best.npy"))


VectorsActual = np.load(os.path.join(path, "vector_data_actual_cartesian.npy"))


VectorsGaussian = np.load(os.path.join(path, "vector_data_gaussian_best.npy"))


params = pd.read_csv(os.path.join(path, "best_gaussian_params.csv"))



B6 = {
    'StokesI_wcs' : StokesI_wcs, 
    'ratios' : ratios,
    'xmin' : xmin,
    'xmax' : xmax,
    'ymin' : ymin,
    'ymax' : ymax, 
    'reference_length_pix' : reference_length_pix,
    'reference_length_AU' : reference_length_AU,
    'BMAJ_pix' : BMAJ_pix, 
    'BMIN_pix' : BMIN_pix, 
    'BPA_deg_cartesian' : BPA_deg_cartesian,
    'max_length_pix' : max_length_pix,
    'reference_fraction' : reference_fraction,
    'phi': params["phi"].iloc[0],
    'BMAJ': params["BMAJ"].iloc[0],
    'BMIN': params["BMIN"].iloc[0],
    'chi2': params["chi2"].iloc[0],
    'VectorsActual': VectorsActual, 
    'VectorsGaussian': VectorsGaussian,
    'POLI_mJy': POLI_debiased_mJy,
    'nx': nx,
    'ny': ny,
    'RA_centre_pix': RA_centre_pix,
    'Dec_centre_pix': Dec_centre_pix,
}
# Out:
# band = Band 6
# max_str = 'J163135.750-240128.700'
# StokesI_wcs CRPIX = [864. 864.]
# StokesI_wcs CDELT = [-5.e-06  5.e-06]
# Pixel scale = 0.018 arcsec/pixel
# Dec_max_pix = 895
#
# In load_band6_data.py, ymax = 895
# In make_vectors: the POLI_err_cutoff is 3
# In make_vectors: the POLI_err_cutoff is 3
# In make_vectors: the POLI_err_cutoff is 3

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND7_nterms2/load_band7_nterms2_data.py"

path = band7_nterms2_data_folder_path

ratios = np.load(os.path.join(path, "GaussianUniformRatios_best.npy"))


VectorsActual = np.load(os.path.join(path, "vector_data_actual_cartesian.npy"))


VectorsGaussian = np.load(os.path.join(path, "vector_data_gaussian_best.npy"))


params = pd.read_csv(os.path.join(path, "best_gaussian_params.csv"))


B7 = {
    'StokesI_wcs' : StokesI_wcs, 
    'ratios' : ratios,
    'xmin' : xmin,
    'xmax' : xmax,
    'ymin' : ymin,
    'ymax' : ymax, 
    'reference_length_pix' : reference_length_pix,
    'reference_length_AU' : reference_length_AU,
    'BMAJ_pix' : BMAJ_pix, 
    'BMIN_pix' : BMIN_pix, 
    'BPA_deg_cartesian' : BPA_deg_cartesian,
    'max_length_pix' : max_length_pix,
    'reference_fraction' : reference_fraction,
    'phi': params["phi"].iloc[0],
    'BMAJ': params["BMAJ"].iloc[0],
    'BMIN': params["BMIN"].iloc[0],
    'chi2': params["chi2"].iloc[0],
    'VectorsActual': VectorsActual, 
    'VectorsGaussian': VectorsGaussian,
    'POLI_mJy': POLI_debiased_mJy,
    'nx': nx,
    'ny': ny,
    'RA_centre_pix': RA_centre_pix,
    'Dec_centre_pix': Dec_centre_pix,
}
# Out:
# band = Band 7 nterms2
# max_str = 'J163135.750-240128.700'
# StokesI_wcs CRPIX = [513. 513.]
# StokesI_wcs CDELT = [-5.e-06  5.e-06]
# Pixel scale = 0.018 arcsec/pixel
# Dec_max_pix = 581
#
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4
# In make_vectors: the POLI_err_cutoff is 4

# %%
def plot_gaussian_ratio_grid(B4, B5, B6, B7, 
                             labels, 
                             cmap = soft_colormap_no_red, 
                             fig_x_size=14, fig_y_size=12,
                             cbar_label="Gaussian Uniform Ratio",
                             vmin=0, vmax=1):

    bands = [B4, B5, B6, B7]
    #labels = ["Band 4", "Band 5", "Band 6", "Band 7"]

    fig = plt.figure(figsize=(fig_x_size, fig_y_size))
    gs = GridSpec(2, 2, figure=fig)

    axes = []

    for i, band_data in enumerate(bands):

        row = i // 2
        col = i % 2

        ax = fig.add_subplot(gs[row, col], projection=band_data['StokesI_wcs'])
        axes.append(ax)

        im = ax.imshow(
            band_data['ratios'],
            origin='lower',
            cmap=cmap,
            vmin=vmin,
            vmax=vmax
        )

        ax.set_xlim(band_data['xmin'], band_data['xmax'])
        ax.set_ylim(band_data['ymin'], band_data['ymax'])

#         ax.text(
#             0.05, 0.90, labels[i],
#             transform=ax.transAxes,
#             fontsize=constants.text_fs,
#             color='black'
#         )
        
        ax.text(
        0.05, 0.35,
        rf"$\phi={band_data['phi']}$" + "\n" +
        rf"BMAJ$={band_data['BMAJ']}$" + "\n" +
        rf"BMIN$={band_data['BMIN']}$" + "\n" +
        rf"$\chi^2={band_data['chi2']:.3f}$",
        transform=ax.transAxes,
        fontsize=constants.text_fs * 0.7,
        color='black',
        va='top',
        ha='left',
#         bbox=dict(facecolor='white', alpha=0.7, edgecolor='none')
    )
        
        

        ax.set_xlabel("Right Ascension (ICRS)", fontsize=constants.axis_label_fs)
        ax.set_ylabel("Declination (ICRS)", fontsize=constants.axis_label_fs)

        ax.tick_params(axis="x", which="major", direction="in", 
                       bottom=True, top=True, length=7, 
                       labelsize=constants.axis_num_fs)

        ax.tick_params(axis="y", which="major", direction="in", 
                       left=True, right=True, length=7, 
                       labelsize=constants.axis_num_fs)
        
        add_band_label(ax, labels[i], 'wavelength', constants)

    # One shared colour bar
    cbar = fig.colorbar(im, ax=axes, orientation='vertical', 
                        fraction=0.035, pad=0.04)

    cbar.set_label(cbar_label, fontsize=constants.cbar_fs)
    cbar.ax.tick_params(labelsize=constants.cbar_num_fs)

    return fig, axes

# %%
fig, axes = plot_gaussian_ratio_grid(
    B4, B5_R1, B6, B7,
    labels = ["Band 4", "Band 5 robust -1", "Band 6", "Band 7"]
)


plt.savefig(writeup_image_folder_path + '/Gaussian/' + "AllGaussian.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %% [markdown]
# # Vector Grid Plot

# %%
def GaussianVectorGrid(B4, B5, B6, B7, labels, 
                       cmap=soft_colormap_no_red, 
                       fig_x_size=14, fig_y_size=12,
                       cbar_label="Gaussian Uniform Ratio",
                       cbar_pad = 0.1,
                       cbar_shrink = 1,
):

    bands = [B4, B5, B6, B7]
    #labels = ["Band 4", "Band 5 robust -1", "Band 6", "Band 7"]

    fig = plt.figure(figsize=(fig_x_size, fig_y_size))
    gs = GridSpec(2, 2, figure=fig)

    axes = []

    for i, band_data in enumerate(bands):

        row = i // 2
        col = i % 2

        ax = fig.add_subplot(gs[row, col], projection=band_data['StokesI_wcs'])
        axes.append(ax)


        # Add data
        # ---------------------------------------------------------------------------
        im = ax.imshow(band_data['POLI_mJy'], cmap=cmap)
        # ---------------------------------------------------------------------------


        # Set axis limits
        # ---------------------------------------------------------------------------
        ax.set_xlim(band_data['xmin'], band_data['xmax'])
        ax.set_ylim(band_data['ymin'], band_data['ymax'])
        # ---------------------------------------------------------------------------

#         ax.text(
#             0.05, 0.90, labels[i],
#             transform=ax.transAxes,
#             fontsize=constants.text_fs,
#             color='black'
#         )
        
        # Colorbar
        # ---------------------------------------------------------------------------
        cbar = fig.colorbar(im, ax=ax, orientation='horizontal', pad=cbar_pad, shrink = cbar_shrink)
        cbar.set_label('Polarized Intensity (mJy/beam)', fontsize=cbar_fs)
        cbar.ax.tick_params(labelsize=cbar_num_fs, which='major', length=7, direction="in")
        cbar.ax.tick_params(which='minor', length=4, direction="in")
        # ---------------------------------------------------------------------------
        
        
        # Axis labels and ticks
        # ---------------------------------------------------------------------------
        if row == 1:
            ax.set_xlabel("Right Ascension", fontsize=constants.axis_label_fs)
            
            ax.tick_params(axis="x", which="major", direction="in", 
                   bottom=True, top=True, length=7, 
                   labelsize=constants.axis_num_fs)
        
        if col == 0 :
            ax.set_ylabel("Declination", fontsize=constants.axis_label_fs)


            ax.tick_params(axis="y", which="major", direction="in", 
                           left=True, right=True, length=7, 
                           labelsize=constants.axis_num_fs)
        # ---------------------------------------------------------------------------

#     # One shared colour bar
#     cbar = fig.colorbar(im, ax=axes, orientation='vertical', 
#                         fraction=0.035, pad=0.04)

#     cbar.set_label(cbar_label, fontsize=constants.cbar_fs)
#     cbar.ax.tick_params(labelsize=constants.cbar_num_fs)

    return fig, axes

# %%
fig, axes = GaussianVectorGrid(
    B4, B5_R1, B6, B7,
    ["Band 4", "Band 5 robust -1", "Band 6", "Band 7"], 
)


plt.savefig(writeup_image_folder_path + '/Gaussian/' + "AllGaussianVector.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %% [markdown]
# # Gaussian Example: Chosen values

# %%
# fig_x_size = 14
# fig_y_size = 12

# cmap=soft_colormap_no_red

# vmin = 0 
# vmax = 1

# cbar_label="Gaussian Uniform Ratio"


# band = B7
# theta_rad = constants.major_angle_rad_cartesian_band7_nterms2

# custom_phi = [2, 3, 4, 7]
# custom_BMAJ = [20, 30, 40, 50]
# custom_BMIN = [50, 40, 30, 20]


# fig = plt.figure(figsize=(fig_x_size, fig_y_size))
# gs = GridSpec(2, 2, figure=fig)

# axes = []

# saving_ratios = []

# for i in range(4):
#     # Set the phi, BMAJ, BMIN values
    
#     phi = custom_phi[i]
#     BMAJ = custom_BMAJ[i]
#     BMIN = custom_BMIN[i]
    
#     print(rf'i = {i} and phi = {phi} and BMAJ = {BMAJ} and BMIN = {BMIN}')

#     GaussianUniformRatios, GaussianAzimuthalRatios, _, _ = gaussian_2d_flat_topped_tilted_model(band['nx'], 
#                                                                                                 band['ny'], 
#                                                                                                 theta_rad, 
#                                                                                                 phi, 
#                                                                                                 BMIN,
#                                                                                                 BMAJ, 
#                                                                                                 band['RA_centre_pix'],
#                                                                                                 band['Dec_centre_pix'])
    
    
    
#     saving_ratios.append(GaussianUniformRatios)
    
    
    
    
#     row = i // 2
#     col = i % 2

#     ax = fig.add_subplot(gs[row, col], projection=band['StokesI_wcs'])
#     axes.append(ax)

#     im = ax.imshow(
#         GaussianUniformRatios,
#         origin='lower',
#         cmap=cmap,
#         vmin=vmin,
#         vmax=vmax
#     )

#     ax.set_xlim(band['xmin'], band['xmax'])
#     ax.set_ylim(band['ymin'], band['ymax'])


#     ax.text(
#     0.05, 0.35,
#     rf"$\phi={phi}$" + "\n" +
#     rf"BMAJ$={BMAJ}$" + "\n" +
#     rf"BMIN$={BMIN}$" + "\n" ,
# #     rf"$\chi^2={band_data['chi2']:.3f}$",
#     transform=ax.transAxes,
#     fontsize=constants.text_fs * 0.7,
#     color='black',
#     va='top',
#     ha='left',
# #         bbox=dict(facecolor='white', alpha=0.7, edgecolor='none')
# )



#     ax.set_xlabel(" ", fontsize= 1)
#     ax.set_ylabel(" ", fontsize= 1)

#     ax.tick_params(axis="x", which="major",
#                    direction="in",
#                    bottom=True, top=True,
#                    length=7,
#                    labelbottom=False)

#     ax.tick_params(axis="y", which="major",
#                    direction="in",
#                    left=True, right=True,
#                    length=7,
#                    labelleft=False)

# # One shared colour bar
# cbar = fig.colorbar(im, ax=axes, orientation='vertical', 
#                     fraction=0.035, pad=0.04)

# cbar.set_label(cbar_label, fontsize=constants.cbar_fs)
# cbar.ax.tick_params(labelsize=constants.cbar_num_fs)


# # Test differences
# print(' ')
# print(rf'Top left and Top right: {np.nansum(saving_ratios[0] - saving_ratios[1])}')

# plt.savefig(writeup_image_folder_path + '/Gaussian/' + "CustomExamples.pdf", 
#             dpi=300, 
#             bbox_inches='tight')

# %%
fig_x_size = 14
fig_y_size = 12

cmap=soft_colormap_no_red

vmin = 0 
vmax = 1

cbar_label="Gaussian Uniform Ratio"


band = B7
theta_rad = constants.major_angle_rad_cartesian_band7_nterms2

custom_phi  = [3, 7]
custom_BMAJ = [40, 50]
custom_BMIN = [30, 20]


fig = plt.figure(figsize=(fig_x_size, fig_y_size))
gs = GridSpec(1, 2, figure=fig, wspace = 0.05)

axes = []

saving_ratios = []

for i in range(2):
    # Set the phi, BMAJ, BMIN values
    
    phi = custom_phi[i]
    BMAJ = custom_BMAJ[i]
    BMIN = custom_BMIN[i]
    
    print(rf'i = {i} and phi = {phi} and BMAJ = {BMAJ} and BMIN = {BMIN}')

    GaussianUniformRatios, GaussianAzimuthalRatios, _, _ = gaussian_2d_flat_topped_tilted_model(band['nx'], 
                                                                                                band['ny'], 
                                                                                                theta_rad, 
                                                                                                phi, 
                                                                                                BMIN,
                                                                                                BMAJ, 
                                                                                                band['RA_centre_pix'],
                                                                                                band['Dec_centre_pix'])
    
    
    
    saving_ratios.append(GaussianUniformRatios)
    
    
    
    
    row = i // 2
    col = i % 2

    ax = fig.add_subplot(gs[row, col], projection=band['StokesI_wcs'])
    axes.append(ax)

    im = ax.imshow(
        GaussianUniformRatios,
        origin='lower',
        cmap=cmap,
        vmin=vmin,
        vmax=vmax
    )

    ax.set_xlim(band['xmin'], band['xmax'])
    ax.set_ylim(band['ymin'], band['ymax'])


    ax.text(
    0.05, 0.25,
    rf"$\phi={phi}$" + "\n" +
    rf"BMAJ$={BMAJ}$" + "\n" +
    rf"BMIN$={BMIN}$" + "\n" ,
#     rf"$\chi^2={band_data['chi2']:.3f}$",
    transform=ax.transAxes,
    fontsize=constants.text_fs * 0.7,
    color='black',
    va='top',
    ha='left',
#         bbox=dict(facecolor='white', alpha=0.7, edgecolor='none')
)



    ax.set_xlabel(" ", fontsize= 1)
    ax.set_ylabel(" ", fontsize= 1)

    ax.tick_params(axis="x", which="major",
                   direction="in",
                   bottom=True, top=True,
                   length=7,
                   labelbottom=False)

    ax.tick_params(axis="y", which="major",
                   direction="in",
                   left=True, right=True,
                   length=7,
                   labelleft=False)

# One shared colour bar
cbar = fig.colorbar(im, ax=axes, orientation='vertical', 
                    fraction=0.045, pad=0.04, shrink = 0.51)

cbar.set_label(cbar_label, fontsize=constants.cbar_fs)
cbar.ax.tick_params(labelsize=constants.cbar_num_fs)


# Test differences
print(' ')
print(rf'Top left and Top right: {np.nansum(saving_ratios[0] - saving_ratios[1])}')

plt.savefig(writeup_image_folder_path + '/Gaussian/' + "CustomExamples.pdf", 
            dpi=300, 
            bbox_inches='tight')
# Out:
# i = 0 and phi = 3 and BMAJ = 40 and BMIN = 30
# i = 1 and phi = 7 and BMAJ = 50 and BMIN = 20
#
# Top left and Top right: 325.6572542761624
