# %%
import numpy as np

# %%
a_arr = [20, 30, 30, 40]
b_arr = [10, 20, 30, 30]

# %%
for i in range(4):
    a = a_arr[i]
    b = b_arr[i]
    
    area = a * b #* (np.pi / (4 * np.log(2)))
    
    print(rf'a = {a} and b = {b} and area = {area:.0f}')
# Out:
# a = 20 and b = 10 and area = 200
# a = 30 and b = 20 and area = 600
# a = 30 and b = 30 and area = 900
# a = 40 and b = 30 and area = 1200
