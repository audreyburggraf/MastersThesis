# %% [markdown]
# In this notebook I am going to try to replicate Figures 11 and 12 from Sadavoy, 2019 (https://ui.adsabs.harvard.edu/abs/2019ApJS..245....2S/abstract)
#
# I am then going to try to adapt it to work for ALMA Band 5 and Band 7

# %% [markdown]
# ## Load Intro Things

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND6/load_band6_data.py"

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/constants.py"

# %% [markdown]
# ## Band 6

# %%
sn_array = [5, 10, 20]

y_cen, x_cen, df, dfs = run_galaxy_contamination("Band 6", sn_array, spacing = 'logspace')
# Out:
# The dr value is: {dr_arcsec} arcsec
#
# The centre position is: (y, x) = (858, 861), and at this position pb = 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_4674/1668714906.py in <module>
#       1 sn_array = [5, 10, 20]
#       2
# ----> 3 y_cen, x_cen, df, dfs = run_galaxy_contamination("Band 6", sn_array, spacing = 'logspace')
#
# ~/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/GalaxyContaminationFunctions.py in run_galaxy_contamination(band, sn_array, spacing, dr_arcsec, print_things)
#     196         for S_min in S:
#     197             # Use your function to integrate dN/dS above threshold
# --> 198             N_per_area = find_N_from_dN_dS(S_min, spacing)
#     199             N_per_area_list.append(N_per_area)
#     200
#
# ~/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/GalaxyContaminationFunctions.py in find_N_from_dN_dS(S_min, spacing)
#      93
#      94         # Compute dN/dS
# ---> 95         dN_dS_grid = np.array([galaxy_probability(s, band) for s in S_grid])
#      96
#      97         # Convert to dN/dlog10S
#
# ~/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/GalaxyContaminationFunctions.py in <listcomp>(.0)
#      93
#      94         # Compute dN/dS
# ---> 95         dN_dS_grid = np.array([galaxy_probability(s, band) for s in S_grid])
#      96
#      97         # Convert to dN/dlog10S
#
# NameError: name 'band' is not defined

# %%
fig, ax = plot_galaxy_contamination_models(df)

# %%
fig, ax = plot_probability_models(dfs, sn_array)

# %%
fig, ax = recreate_figs_11_12_sadavoy2019(dfs, sn_array)

# %% [markdown]
# ## Find probability

# %%
# # Check it the function way:
# GC_probability(x_cen, y_cen, df, dfs, StokesI_mJy, sn_array, "Band 7", distance = "x", print_things = True)
