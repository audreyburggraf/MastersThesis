# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/GalaxyContamination.py"

# %%
from scipy.optimize import *

from scipy import interpolate

# %% [markdown]
# ## Print out df to confirm information is correct

# %%
# This should be the cumulitive infromation from Table 2 
df_cumulative_Chen
