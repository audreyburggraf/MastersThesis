# %%
# %run constants.py

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"

# %%
df_StokesI_BAND4 = pd.read_csv(band4_carta_folder_path + "IRS63_my_slice_StokesI_BAND4.csv")  

# Unpack into original variables
StokesI_major_BAND4         = df_StokesI_BAND4["StokesI_major"].values
StokesI_offset_major_BAND4  = df_StokesI_BAND4["StokesI_offset_major"].values
StokesI_minor_BAND4         = df_StokesI_BAND4["StokesI_minor"].values
StokesI_offset_minor_BAND4  = df_StokesI_BAND4["StokesI_offset_minor"].values

# %%
df_POLI_BAND4 = pd.read_csv(band4_carta_folder_path + "IRS63_my_slice_POLI_BAND4.csv")  

# Unpack into original variables
POLI_major_BAND4         = df_POLI_BAND4["POLI_major"].values
POLI_offset_major_BAND4  = df_POLI_BAND4["POLI_offset_major"].values
POLI_minor_BAND4         = df_POLI_BAND4["POLI_minor"].values
POLI_offset_minor_BAND4  = df_POLI_BAND4["POLI_offset_minor"].values

# %%
df_StokesI_BAND6 = pd.read_csv(band6_carta_folder_path + "IRS63_my_slice_StokesI_BAND6.csv")  

# Unpack into original variables
StokesI_major_BAND6         = df_StokesI_BAND6["StokesI_major"].values
StokesI_offset_major_BAND6  = df_StokesI_BAND6["StokesI_offset_major"].values
StokesI_minor_BAND6         = df_StokesI_BAND6["StokesI_minor"].values
StokesI_offset_minor_BAND6  = df_StokesI_BAND6["StokesI_offset_minor"].values

# %%
df_POLI_BAND6 = pd.read_csv(band6_carta_folder_path + "IRS63_my_slice_POLI_BAND6.csv")  

# Unpack into original variables
POLI_major_BAND6         = df_POLI_BAND6["POLI_major"].values
POLI_offset_major_BAND6  = df_POLI_BAND6["POLI_offset_major"].values
POLI_minor_BAND6         = df_POLI_BAND6["POLI_minor"].values
POLI_offset_minor_BAND6  = df_POLI_BAND6["POLI_offset_minor"].values

# %%
colors = ['blue', 'red', 'darkorange', 'limegreen']

vline_color = 'black'

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

lw = 5

# Major axis
ax[0].plot(StokesI_offset_major_BAND4, StokesI_major_BAND4, 
           color= colors[0], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[0].plot(StokesI_offset_major_BAND6, StokesI_major_BAND6, 
           color= colors[2], 
           ls='--', 
           lw=lw, 
           label="BAND 6")

# Minor axis
ax[1].plot(StokesI_offset_minor_BAND4, StokesI_minor_BAND4, 
           color= colors[1], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[1].plot(StokesI_offset_minor_BAND6, StokesI_minor_BAND6, 
           color= colors[3], 
           ls='--', 
           lw=lw, 
           label="BAND 6")


ax[0].axvline(0, color = vline_color, linestyle='-', linewidth=3)
ax[1].axvline(0, color = vline_color, linestyle='-', linewidth=3)


# Titles and labels
ax[0].set_title("Major Axis Data", fontsize=title_fs)
ax[1].set_title("Minor Axis Data", fontsize=title_fs)

for i in range(2):
    ax[i].set_xlabel("Offset (arcsec)", fontsize=axis_label_fs)
    ax[i].set_ylabel("Stokes I (mJy/beam)", fontsize=axis_label_fs)
    ax[i].legend(fontsize=legend_text_fs)
    ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=axis_num_fs)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

lw = 5

# Major axis
ax[0].plot(POLI_offset_major_BAND4, POLI_major_BAND4, 
           color= colors[0], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[0].plot(POLI_offset_major_BAND6, POLI_major_BAND6, 
           color= colors[2], 
           ls='--', 
           lw=lw, 
           label="BAND 6")

# Minor axis
ax[1].plot(POLI_offset_minor_BAND4, POLI_minor_BAND4, 
           color= colors[1], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[1].plot(POLI_offset_minor_BAND6, POLI_minor_BAND6, 
           color= colors[3], 
           ls='--', 
           lw=lw, 
           label="BAND 6")


ax[0].axvline(0, color = vline_color, linestyle='-', linewidth=3)
ax[1].axvline(0, color = vline_color, linestyle='-', linewidth=3)


# Titles and labels
ax[0].set_title("Major Axis Data", fontsize=title_fs)
ax[1].set_title("Minor Axis Data", fontsize=title_fs)

for i in range(2):
    ax[i].set_xlabel("Offset (arcsec)", fontsize=axis_label_fs)
    ax[i].set_ylabel("Polarized intensity (mJy/beam)", fontsize=axis_label_fs)
    ax[i].legend(fontsize=legend_text_fs)
    ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=axis_num_fs)
