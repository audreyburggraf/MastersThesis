# %%
# %run constants.py

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"

# %% [markdown]
# # Plotting Function

# %%
def plot_3_slices(offset_minor_BAND4, offset_minor_BAND6, offset_minor_BAND7,
                  offset_major_BAND4, offset_major_BAND6, offset_major_BAND7,
                  minor_BAND4, minor_BAND6, minor_BAND7,
                  major_BAND4, major_BAND6, major_BAND7,
                  y_label,
                  show_y_label=False,
                  plot_major=False,
                  plot_minor=True,
                  titles=False,
                  vline_lw=3,
                  lw=5,
                  cb = False):
    
    if cb:
        colors = sns.color_palette('colorblind', 6)
    else:
        colors = sns.color_palette('bright', 6)
    
    fig, ax = plt.subplots(1, 3, figsize=(21, 6))  # 3 plots in one row

    # Plot the minor axis data
    if plot_minor:
        ax[0].plot(offset_minor_BAND4, minor_BAND4, color=colors[0], ls='-', lw=lw, label="Minor Axis")
        ax[1].plot(offset_minor_BAND6, minor_BAND6, color=colors[2], ls='-', lw=lw, label="Minor Axis")
        ax[2].plot(offset_minor_BAND7, minor_BAND7, color=colors[4], ls='-', lw=lw, label="Minor Axis")

    # Plot the major axis data
    if plot_major:
        ax[0].plot(offset_major_BAND4, major_BAND4, color=colors[1], ls='-', lw=lw, label="Major Axis")
        ax[1].plot(offset_major_BAND6, major_BAND6, color=colors[3], ls='-', lw=lw, label="Major Axis")
        ax[2].plot(offset_major_BAND7, major_BAND7, color=colors[5], ls='-', lw=lw, label="Major Axis")

    # Plot a vertical line at (0,0)
    for i in range(3):
        ax[i].axvline(0, color=vline_color, linestyle='-', linewidth=vline_lw)

    # Set titles
    if titles:
        ax[0].set_title("BAND 4", fontsize=title_fs)
        ax[1].set_title("BAND 6", fontsize=title_fs)
        ax[2].set_title("BAND 7", fontsize=title_fs)

    # Set y-label if desired
    if show_y_label:
        ax[0].set_ylabel(y_label, fontsize=35)

    # Set x-labels and formatting
    for i in range(3):
        ax[i].set_xlabel("Offset (arcsec)", fontsize=35)
        ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=35)

    plt.tight_layout()

    return fig, ax

# %% [markdown]
# # Load Band 4 Data

# %%
df_StokesI_BAND4 = pd.read_csv(band4_carta_folder_path + "IRS63_my_slice_StokesI_BAND4.csv")  

# Unpack into original variables
StokesI_major_BAND4         = df_StokesI_BAND4["StokesI_major"].values
StokesI_offset_major_BAND4  = df_StokesI_BAND4["StokesI_offset_major"].values
StokesI_minor_BAND4         = df_StokesI_BAND4["StokesI_minor"].values
StokesI_offset_minor_BAND4  = df_StokesI_BAND4["StokesI_offset_minor"].values

# %%
df_POLI_BAND4 = pd.read_csv(band4_carta_folder_path + "IRS63_my_slice_POLI_BAND4.csv")  

# Unpack into original variables
POLI_major_BAND4         = df_POLI_BAND4["POLI_major"].values
POLI_offset_major_BAND4  = df_POLI_BAND4["POLI_offset_major"].values
POLI_minor_BAND4         = df_POLI_BAND4["POLI_minor"].values
POLI_offset_minor_BAND4  = df_POLI_BAND4["POLI_offset_minor"].values

# %%
df_POLF_BAND4 = pd.read_csv(band4_carta_folder_path + "IRS63_my_slice_POLF_BAND4.csv")  

# Unpack into original variables
POLF_major_BAND4         = df_POLF_BAND4["POLF_major"].values
POLF_offset_major_BAND4  = df_POLF_BAND4["POLF_offset_major"].values
POLF_minor_BAND4         = df_POLF_BAND4["POLF_minor"].values
POLF_offset_minor_BAND4  = df_POLF_BAND4["POLF_offset_minor"].values

# %% [markdown]
# # Load Band 6 Data

# %%
df_StokesI_BAND6 = pd.read_csv(band6_carta_folder_path + "IRS63_my_slice_StokesI_BAND6.csv")  

# Unpack into original variables
StokesI_major_BAND6         = df_StokesI_BAND6["StokesI_major"].values
StokesI_offset_major_BAND6  = df_StokesI_BAND6["StokesI_offset_major"].values
StokesI_minor_BAND6         = df_StokesI_BAND6["StokesI_minor"].values
StokesI_offset_minor_BAND6  = df_StokesI_BAND6["StokesI_offset_minor"].values

# %%
df_POLI_BAND6 = pd.read_csv(band6_carta_folder_path + "IRS63_my_slice_POLI_BAND6.csv")  

# Unpack into original variables
POLI_major_BAND6         = df_POLI_BAND6["POLI_major"].values
POLI_offset_major_BAND6  = df_POLI_BAND6["POLI_offset_major"].values
POLI_minor_BAND6         = df_POLI_BAND6["POLI_minor"].values
POLI_offset_minor_BAND6  = df_POLI_BAND6["POLI_offset_minor"].values

# %%
df_POLF_BAND6 = pd.read_csv(band6_carta_folder_path + "IRS63_my_slice_POLF_BAND6.csv")  

# Unpack into original variables
POLF_major_BAND6         = df_POLF_BAND6["POLF_major"].values
POLF_offset_major_BAND6  = df_POLF_BAND6["POLF_offset_major"].values
POLF_minor_BAND6         = df_POLF_BAND6["POLF_minor"].values
POLF_offset_minor_BAND6  = df_POLF_BAND6["POLF_offset_minor"].values

# %% [markdown]
# # Band 7 Data

# %%
# Plot BAND 7 (right) – dummy zero data
import numpy as np

mock_offset = np.linspace(-1, 1, 100)
mock_data   = np.linspace(0 , 1, 100)

# %%
# StokesI_major_BAND7         = np.array(mock_data)
# StokesI_offset_major_BAND7  = np.array(mock_offset)
# StokesI_minor_BAND7         = np.array(mock_data)
# StokesI_offset_minor_BAND7  = np.array(mock_offset)



df_StokesI_BAND7 = pd.read_csv(band7_carta_folder_path + "IRS63_my_slice_StokesI_BAND7.csv")  

# Unpack into original variables
StokesI_major_BAND7         = df_StokesI_BAND7["StokesI_major"].values
StokesI_offset_major_BAND7  = df_StokesI_BAND7["StokesI_offset_major"].values
StokesI_minor_BAND7         = df_StokesI_BAND7["StokesI_minor"].values
StokesI_offset_minor_BAND7  = df_StokesI_BAND7["StokesI_offset_minor"].values

# %%
# POLI_major_BAND7         = StokesI_major_BAND7
# POLI_offset_major_BAND7  = StokesI_offset_major_BAND7
# POLI_minor_BAND7         = StokesI_minor_BAND7 
# POLI_offset_minor_BAND7  = StokesI_offset_minor_BAND7


df_POLI_BAND7 = pd.read_csv(band7_carta_folder_path + "IRS63_my_slice_POLI_BAND7.csv")  

# Unpack into original variables
POLI_major_BAND7         = df_POLI_BAND7["POLI_major"].values
POLI_offset_major_BAND7  = df_POLI_BAND7["POLI_offset_major"].values
POLI_minor_BAND7         = df_POLI_BAND7["POLI_minor"].values
POLI_offset_minor_BAND7  = df_POLI_BAND7["POLI_offset_minor"].values

# %%
POLF_major_BAND7         = StokesI_major_BAND7
POLF_offset_major_BAND7  = StokesI_offset_major_BAND7
POLF_minor_BAND7         = StokesI_minor_BAND7 
POLF_offset_minor_BAND7  = StokesI_offset_minor_BAND7

# %% [markdown]
# # Plot

# %%
colors = ['blue', 'red', 'darkorange', 'limegreen']

vline_color = 'black'

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

lw = 5

# Major axis
ax[0].plot(StokesI_offset_major_BAND4, StokesI_major_BAND4, 
           color= colors[0], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[0].plot(StokesI_offset_major_BAND6, StokesI_major_BAND6, 
           color= colors[2], 
           ls='--', 
           lw=lw, 
           label="BAND 6")

# Minor axis
ax[1].plot(StokesI_offset_minor_BAND4, StokesI_minor_BAND4, 
           color= colors[1], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[1].plot(StokesI_offset_minor_BAND6, StokesI_minor_BAND6, 
           color= colors[3], 
           ls='--', 
           lw=lw, 
           label="BAND 6")


ax[0].axvline(0, color = vline_color, linestyle='-', linewidth=3)
ax[1].axvline(0, color = vline_color, linestyle='-', linewidth=3)


# Titles and labels
ax[0].set_title("Major Axis Data", fontsize=title_fs)
ax[1].set_title("Minor Axis Data", fontsize=title_fs)

for i in range(2):
    ax[i].set_xlabel("Offset (arcsec)", fontsize=axis_label_fs)
    ax[i].set_ylabel("Stokes I (mJy/beam)", fontsize=axis_label_fs)
    ax[i].legend(fontsize=legend_text_fs)
    ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=axis_num_fs)
    
    
plt.savefig(image_folder_path + "IRS63_mw_slice_StokesI.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
fig, ax = plot_3_slices(StokesI_offset_minor_BAND4, StokesI_offset_minor_BAND6, StokesI_offset_minor_BAND7,
                        StokesI_offset_major_BAND4, StokesI_offset_major_BAND6, StokesI_offset_major_BAND7,
                        StokesI_minor_BAND4, StokesI_minor_BAND6, StokesI_minor_BAND7,
                        StokesI_major_BAND4, StokesI_major_BAND6, StokesI_major_BAND7,
                        'Stokes I (mJy/beam)',
                        cb = False)
    
    
plt.savefig(slideshow_image_folder_path + "IRS63_mw_slice_StokesI.jpeg", 
        dpi=300, 
        bbox_inches='tight')

# %% [markdown]
# # Polarized Intensity

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

lw = 5

# Major axis
ax[0].plot(POLI_offset_major_BAND4, POLI_major_BAND4, 
           color= colors[0], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[0].plot(POLI_offset_major_BAND6, POLI_major_BAND6, 
           color= colors[2], 
           ls='-', 
           lw=lw, 
           label="BAND 6")

# Minor axis
ax[1].plot(POLI_offset_minor_BAND4, POLI_minor_BAND4, 
           color= colors[1], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[1].plot(POLI_offset_minor_BAND6, POLI_minor_BAND6, 
           color= colors[3], 
           ls='-', 
           lw=lw, 
           label="BAND 6")


ax[0].axvline(0, color = vline_color, linestyle='-', linewidth=3)
ax[1].axvline(0, color = vline_color, linestyle='-', linewidth=3)


# Titles and labels
ax[0].set_title("Major Axis Data", fontsize=title_fs)
ax[1].set_title("Minor Axis Data", fontsize=title_fs)

for i in range(2):
    ax[i].set_xlabel("Offset (arcsec)", fontsize=axis_label_fs)
    ax[i].set_ylabel("Polarized Intensity (mJy/beam)", fontsize=axis_label_fs)
    ax[i].legend(fontsize=legend_text_fs)
    ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=axis_num_fs)
    
    
plt.savefig(image_folder_path + "IRS63_mw_slice_POLI.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
fig, ax = plot_3_slices(POLI_offset_minor_BAND4, POLI_offset_minor_BAND6, POLI_offset_minor_BAND7,
                        POLI_offset_major_BAND4, POLI_offset_major_BAND6, POLI_offset_major_BAND7,
                        POLI_minor_BAND4, POLI_minor_BAND6, POLI_minor_BAND7,
                        POLI_major_BAND4, POLI_major_BAND6, POLI_major_BAND7,
                        'POLI (mJy/beam)',
                        cb = False)
    
    
plt.savefig(slideshow_image_folder_path + "IRS63_mw_slice_POLI.jpeg", 
        dpi=300, 
        bbox_inches='tight')

# %% [markdown]
# # Polarized Fraction

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

lw = 5

# Major axis
ax[0].plot(POLF_offset_major_BAND4, POLF_major_BAND4, 
           color= colors[0], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[0].plot(POLF_offset_major_BAND6, POLF_major_BAND6, 
           color= colors[2], 
           ls='-', 
           lw=lw, 
           label="BAND 6")

# Minor axis
ax[1].plot(POLF_offset_minor_BAND4, POLF_minor_BAND4, 
           color= colors[1], 
           ls='-', 
           lw=lw, 
           label="BAND 4")

ax[1].plot(POLF_offset_minor_BAND6, POLF_minor_BAND6, 
           color= colors[3], 
           ls='-', 
           lw=lw, 
           label="BAND 6")


ax[0].axvline(0, color = vline_color, linestyle='-', linewidth=3)
ax[1].axvline(0, color = vline_color, linestyle='-', linewidth=3)


# Titles and labels
ax[0].set_title("Major Axis Data", fontsize=title_fs)
ax[1].set_title("Minor Axis Data", fontsize=title_fs)

for i in range(2):
    ax[i].set_xlabel("Offset (arcsec)", fontsize=axis_label_fs)
    ax[i].set_ylabel("Polarized Fraction", fontsize=axis_label_fs)
    ax[i].legend(fontsize=legend_text_fs)
    ax[i].tick_params(axis="both", which="major", direction="in", length=7, labelsize=axis_num_fs)
    
    
    
plt.savefig(image_folder_path + "IRS63_mw_slice_POLF.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
fig, ax = plot_3_slices(POLF_offset_minor_BAND4, POLF_offset_minor_BAND6, POLF_offset_minor_BAND7,
                        POLF_offset_major_BAND4, POLF_offset_major_BAND6, POLF_offset_major_BAND7,
                        POLF_minor_BAND4, POLF_minor_BAND6, POLF_minor_BAND7,
                        POLF_major_BAND4, POLF_major_BAND6, POLF_major_BAND7,
                        'POLF (mJy/beam)',
                        cb = False)
    
    
plt.savefig(slideshow_image_folder_path + "IRS63_mw_slice_POLF.jpeg", 
        dpi=300, 
        bbox_inches='tight')
