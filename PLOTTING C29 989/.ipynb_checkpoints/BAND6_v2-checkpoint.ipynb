# %%
# %run constants.py
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FITS FILES/BAND6/load_band6_data.py"

# %%
# StokesI_header


GetInfoFromHeader(StokesI_header)
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                 1726
# NAXIS2  =                 1726
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   7.369120915731E-05
# BMIN    =   5.658831033442E-05
# BPA     =  -6.855334082679E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'c2d_989 '
#
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -2.402480206384E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =  -1.121014558665E+02
# CDELT1  =  -5.000000000000E-06
# CRPIX1  =   8.640000000000E+02
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =  -2.402480206384E+01
# CDELT2  =   5.000000000000E-06
# CRPIX2  =   8.640000000000E+02
# CUNIT2  = 'deg     '
# CTYPE3  = 'FREQ    '
# CRVAL3  =   2.330104170176E+11
# CDELT3  =   2.002083403519E+10
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'Hz      '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   2.240000000001E+11 /Rest Frequency (Hz)
# SPECSYS = 'TOPOCENT'           /Spectral reference frame
# ALTRVAL =  -1.205917439857E+07
# ALTRPIX =   1.000000000000E+00
# VELREF  =                  259 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# OBSERVER= 'ssadavoy'
# DATE-OBS= '2017-05-20T02:10:57.888000'
# TIMESYS = 'UTC     '
# OBSRA   =   2.478985416666E+02
# OBSDEC  =  -2.402480555558E+01
# OBSGEO-X=   2.225142180269E+06
# OBSGEO-Y=  -5.440307370349E+06
# OBSGEO-Z=  -2.481029851874E+06
# DATE    = '2019-04-02T18:46:31.247000' /Date FITS file was written
# ORIGIN  = 'CASA 5.1.1-5'
# HISTORY CASA START LOGTABLE
# HISTORY 2017-11-09T21:21:12 INFO SRCCODE='imager::clean()'
# HISTORY 2017-09-13T13:12:51 INFO SRCCODE='::importasdm'
# HISTORY 2017-09-13T16:09:51 INFO SRCCODE='::imager::setjy()'
# HISTORY CLI_COMM: []; MESSAGE:      224.984         2.12499
# HISTORY 2017-09-13T16:09:51 INFO SRCCODE='::imager::setjy()'
# HISTORY CLI_COMM: []; MESSAGE:      226.984         2.12058
# HISTORY 2017-09-13T16:09:51 INFO SRCCODE='::imager::setjy()'
# HISTORY CLI_COMM: []; MESSAGE:      239.016         2.09502
# HISTORY 2017-09-13T16:09:51 INFO SRCCODE='::imager::setjy()'
# HISTORY CLI_COMM: []; MESSAGE:      241.016         2.09092
# HISTORY 2017-09-13T16:31:39 INFO SRCCODE='::calibrater::fluxscale()'
# HISTORY CLI_COMM: []; MESSAGE: Table uid___A002_Xc079b5_X8b4.ms.split.ampli_inf
# HISTORY > is of type: T Jones
# HISTORY 2017-09-13T16:31:40 INFO SRCCODE='::calibrater::fluxscale()'
# HISTORY CLI_COMM: []; MESSAGE: Storing result in uid___A002_Xc079b5_X8b4.ms.spli
# HISTORY >t.flux_inf
# HISTORY 2017-09-13T16:31:41 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: taskname=fluxscale
# HISTORY 2017-09-13T16:31:41 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "uid___A002_Xc079b5_X8b4.ms.split"
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: caltable    = "uid___A002_Xc079b5_X8b4.ms.split.a
# HISTORY >mpli_inf"
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: fluxtable   = "uid___A002_Xc079b5_X8b4.ms.split.f
# HISTORY >lux_inf"
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: reference   = ['1']
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: transfer    = ['']
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: listfile    = ""
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: append      = False
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: refspwmap   = [-1]
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: gainthreshold = -1.0
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: incremental = False
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: fitorder    = 1
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: display     = False
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: Fluxscale results *****
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: J1549+0237(field id=0)
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 0(freq = 224.000GHz) Flux density =   2.287
# HISTORY >319+/-  0.001830 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 1(freq = 226.000GHz) Flux density =   2.271
# HISTORY >759+/-  0.001848 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 2(freq = 240.000GHz) Flux density =   2.200
# HISTORY >677+/-  0.001970 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 3(freq = 242.000GHz) Flux density =   2.191
# HISTORY >294+/-  0.001965 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spectral index fitting coefficients [zero-point
# HISTORY >, alpha, beta] with errors :[0.350,-0.546,0.000]+/-[0.000,0.015,0.000]
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Fitted flux density =   2.237366+/-  0.001180 J
# HISTORY >y (reference freq = 232.860GHz)
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE: J1625-2527(field id=2)
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 0(freq = 224.000GHz) Flux density =   0.386
# HISTORY >763+/-  0.001070 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 1(freq = 226.000GHz) Flux density =   0.387
# HISTORY >151+/-  0.001068 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 2(freq = 240.000GHz) Flux density =   0.371
# HISTORY >252+/-  0.001147 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spw 3(freq = 242.000GHz) Flux density =   0.370
# HISTORY >390+/-  0.001077 Jy
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Spectral index fitting coefficients [zero-point
# HISTORY >, alpha, beta] with errors :[-0.422,-0.610,0.000]+/-[0.001,0.052,0.000]
# HISTORY 2017-09-13T16:31:42 INFO SRCCODE='::fluxscale'
# HISTORY CLI_COMM: []; MESSAGE:   Fitted flux density =   0.378830+/-  0.000686 J
# HISTORY >y (reference freq = 232.860GHz)
# HISTORY 2017-09-13T16:36:41 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "uid___A002_Xc079b5_X8b4.ms.split"
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "0"
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['uid___A002_Xc079b5_X8b4.ms.split.
# HISTORY >bandpass', 'uid___A002_Xc079b5_X8b4.ms.split.phase_int', 'uid___A002_Xc
# HISTORY >9b5_X8b4.ms.split.flux_inf']
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['', '0', '0']
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['linear,linear']
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [True, True, True]
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = False
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T16:36:42 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "uid___A002_Xc079b5_X8b4.ms.split"
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "1"
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['uid___A002_Xc079b5_X8b4.ms.split.
# HISTORY >bandpass', 'uid___A002_Xc079b5_X8b4.ms.split.phase_int', 'uid___A002_Xc
# HISTORY >9b5_X8b4.ms.split.flux_inf']
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['', '1', '1']
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['linear,linear']
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [True, True, True]
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = False
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T16:37:08 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "uid___A002_Xc079b5_X8b4.ms.split"
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "2,3~31"
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T16:39:46 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['uid___A002_Xc079b5_X8b4.ms.split.
# HISTORY >bandpass', 'uid___A002_Xc079b5_X8b4.ms.split.phase_inf', 'uid___A002_Xc
# HISTORY >9b5_X8b4.ms.split.flux_inf']
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['', '2', '2']
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['linear,linear']
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [True, True, True]
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = False
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T16:39:47 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T16:42:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: taskname=split
# HISTORY 2017-09-13T16:42:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T16:42:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "uid___A002_Xc079b5_X8b4.ms.split"
# HISTORY 2017-09-13T16:42:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: outputvis   = "uid___A002_Xc079b5_X8b4.ms.split.c
# HISTORY >al"
# HISTORY 2017-09-13T16:42:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: keepmms     = True
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: field       = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: correlation = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: intent      = "CALIBRATE_BANDPASS#ON_SOURCE,CALIB
# HISTORY >RATE_FLUX#ON_SOURCE,CALIBRATE_PHASE#ON_SOURCE,CALIBRATE_POLARIZATION#ON
# HISTORY >OURCE,CALIBRATE_WVR#AMBIENT,CALIBRATE_WVR#HOT,CALIBRATE_WVR#OFF_SOURCEC
# HISTORY >LIBRATE_WVR#ON_SOURCE,OBSERVE_CHECK_SOURCE#ON_SOURCE,OBSERVE_TARGET#O_S
# HISTORY >URCE"
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: array       = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T16:42:17 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: feed        = ""
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: datacolumn  = "corrected"
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: keepflags   = True
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: width       = 1
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: timebin     = "0s"
# HISTORY 2017-09-13T16:42:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: combine     = ""
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: taskname=concat
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: vis          = "['uid___A002_Xc079b5_Xd0a.ms.spli
# HISTORY >t.cal']"
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: concatvis    = "concat.ms"
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: freqtol      = ""
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: dirtol       = ""
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: respectname  = "False"
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: copypointing = "True"
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: visweightscale = "[0, 0]"
# HISTORY 2017-09-13T18:52:18 INFO SRCCODE='::concat'
# HISTORY CLI_COMM: []; MESSAGE: forcesingleephemfield = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "concat.ms"
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "1"
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T19:13:33 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['concat.ms.Gxyamp', 'concat.ms.Kcr
# HISTORY >s', 'concat.ms.XY0', 'concat.ms.Df0gen']
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['0', '0', '0', '0']
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['nearest', 'nearest', 'nearest', '
# HISTORY >nearest']
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False, False, False, False]
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = True
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T19:13:34 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "concat.ms"
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "3"
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['concat.ms.Gxyamp', 'concat.ms.Kcr
# HISTORY >s', 'concat.ms.XY0', 'concat.ms.Df0gen']
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['0', '0', '0', '0']
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['nearest', 'nearest', 'nearest', '
# HISTORY >nearest']
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False, False, False, False]
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = True
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T19:14:13 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T19:15:49 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T19:15:49 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T19:15:49 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "concat.ms"
# HISTORY 2017-09-13T19:15:49 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "2"
# HISTORY 2017-09-13T19:15:49 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['concat.ms.Gxyamp', 'concat.ms.Kcr
# HISTORY >s', 'concat.ms.XY0', 'concat.ms.Df0gen']
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['0', '0', '0', '0']
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['nearest', 'nearest', 'nearest', '
# HISTORY >nearest']
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False, False, False, False]
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = True
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T19:15:50 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "concat.ms"
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "4~31"
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-09-13T19:23:15 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['concat.ms.Gxyamp', 'concat.ms.Kcr
# HISTORY >s', 'concat.ms.XY0', 'concat.ms.Df0gen']
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['0', '0', '0', '0']
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['nearest', 'nearest', 'nearest', '
# HISTORY >nearest']
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = []
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False, False, False, False]
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = True
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-09-13T19:23:16 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-09-13T19:27:24 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-09-13T19:27:24 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-09-13T19:27:24 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "concat.ms"
# HISTORY 2017-09-13T19:27:24 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = "0"
# HISTORY 2017-09-13T19:27:24 INFO SRCCODE='::applycal'
# ...
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['pcal3b']
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['']
# HISTORY 2017-11-09T21:09:11 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['linear']
# HISTORY 2017-11-09T21:09:12 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = [[0, 0, 0, 0]]
# HISTORY 2017-11-09T21:09:12 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False]
# HISTORY 2017-11-09T21:09:12 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = False
# HISTORY 2017-11-09T21:09:12 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-11-09T21:09:12 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: taskname=applycal
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "calibrated_final_split.ms"
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: field       = ""
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-11-09T21:09:17 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: selectdata  = True
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = "2017/07/12/12:00:00~2017/07/15/00:
# HISTORY >00:00"
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: msselect    = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: docallib    = False
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: callib      = ""
# HISTORY 2017-11-09T21:09:18 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gaintable   = ['pcal3c']
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: gainfield   = ['']
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: interp      = ['linear']
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: spwmap      = [[0, 0, 0, 0]]
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: calwt       = [False]
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: parang      = False
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: applymode   = "calflag"
# HISTORY 2017-11-09T21:09:19 INFO SRCCODE='::applycal'
# HISTORY CLI_COMM: []; MESSAGE: flagbackup  = False
# HISTORY 2017-11-09T21:11:58 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: taskname=split
# HISTORY 2017-11-09T21:12:01 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: version: 4.7.2 branches rev. 39762 Wed 2017/03/08
# HISTORY > 12:39:14 UTC
# HISTORY 2017-11-09T21:12:04 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: vis         = "calibrated_final_split.ms"
# HISTORY 2017-11-09T21:12:07 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: outputvis   = "calibrated_final_v2.c2d1008a.selfc
# HISTORY >al"
# HISTORY 2017-11-09T21:12:10 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: keepmms     = True
# HISTORY 2017-11-09T21:12:13 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: field       = ""
# HISTORY 2017-11-09T21:12:16 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: spw         = ""
# HISTORY 2017-11-09T21:12:18 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: scan        = ""
# HISTORY 2017-11-09T21:12:21 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: antenna     = ""
# HISTORY 2017-11-09T21:12:24 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: correlation = ""
# HISTORY 2017-11-09T21:12:27 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: timerange   = ""
# HISTORY 2017-11-09T21:12:30 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: intent      = ""
# HISTORY 2017-11-09T21:12:33 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: array       = ""
# HISTORY 2017-11-09T21:12:36 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: uvrange     = ""
# HISTORY 2017-11-09T21:12:39 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: observation = ""
# HISTORY 2017-11-09T21:12:42 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: feed        = ""
# HISTORY 2017-11-09T21:12:47 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: datacolumn  = "corrected"
# HISTORY 2017-11-09T21:12:50 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: keepflags   = True
# HISTORY 2017-11-09T21:12:53 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: width       = 1
# HISTORY 2017-11-09T21:13:07 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: timebin     = "0s"
# HISTORY 2017-11-09T21:13:07 INFO SRCCODE='::split'
# HISTORY CLI_COMM: []; MESSAGE: combine     = ""
# HISTORY 2017-11-09T21:13:21 INFO SRCCODE='::imager::defineimage()'
# HISTORY CLI_COMM: [Defining image properties:nx=1728 ny=1728 cellx='0.018arcsec'
# HISTORY > celly='0.018arcsec' stokes=I' mode=MFS nchan=-1 start=0 step=1 spwids=
# HISTORY >1] fieldid=-1 facets=1 frame=5 distance='0',  phaseCenter='16:31:35.65
# HISTORY >  335.58.30.70, ' mStart='Radialvelocity: 0' qStep='0 '' mFreqStart='Fr
# HISTORY >uency: 0]; MESSAGE:
# HISTORY 2017-11-09T21:13:23 INFO SRCCODE='::imager::weight()'
# HISTORY CLI_COMM: []; MESSAGE: Weighting MS: Imaging weights will be changed
# HISTORY 2017-11-09T21:13:23 INFO SRCCODE='::imager::weight()'
# HISTORY CLI_COMM: []; MESSAGE: Briggs weighting: sidelobes will be suppressed ov
# HISTORY >er full image
# HISTORY 2017-11-09T21:13:26 INFO SRCCODE='::imager::filter()'
# HISTORY CLI_COMM: []; MESSAGE: Imaging weights will be tapered
# HISTORY 2017-11-09T21:20:14 INFO SRCCODE='::imager::clean()'
# HISTORY CLI_COMM: []; MESSAGE: Clean gain = 0.1, Niter = 99500, Threshold = 0.1
# HISTORY > mJy
# HISTORY 2017-11-09T21:20:14 INFO SRCCODE='::imager::clean()'
# HISTORY CLI_COMM: []; MESSAGE: Continuing deconvolution
# HISTORY 2017-11-09T21:21:11 INFO SRCCODE='::imager::clean()'
# HISTORY CLI_COMM: []; MESSAGE: Successfully deconvolved image
# HISTORY 2017-11-09T21:21:11 INFO SRCCODE='::imager::iClean()'
# HISTORY CLI_COMM: []; MESSAGE: Restoring Image(s) with the clean-beam
# HISTORY 2017-11-09T21:40:57 INFO SRCCODE='::image::pbcor'
# HISTORY Ran ia.pbcor
# HISTORY 2017-11-09T21:40:57 INFO SRCCODE='::image::pbcor'
# HISTORY ia.pbcor(pbimage="c2d_989_StokesI_clean_selfcal_v2.flux", outfile="c2d_9
# HISTORY >89_StokesI_clean_selfcal_v2.pbcor", overwrite=false, box="", region="",
# HISTORY > chans="", stokes="", mask="", mode="divide", cutoff=-1.000000, stretch
# HISTORY >alse)
# HISTORY 2019-04-02T18:46:25 INFO SRCCODE='::image::pad'
# HISTORY Ran ia.pad
# HISTORY 2019-04-02T18:46:25 INFO SRCCODE='::image::pad'
# HISTORY ia.pad(outfile="", npixels=1, value=0.000000, padmask=false, overwrite=f
# HISTORY >alse, region=[], box="", chans="", stokes="", mask="", stretch=false, w
# HISTORY >ntreturn=true)
# HISTORY 2019-04-02T18:46:25 INFO SRCCODE='::ImagePadder::_reportOldNewImageShape
# HISTORY >s'
# HISTORY Original /h/manticore0/alma/cycle3_pol/debiased/icrs/c2d_989_StokesI_cle
# HISTORY >an_selfcal_v2_pbcor.fits size => [1728, 1728, 1, 1]
# HISTORY 2019-04-02T18:46:25 INFO SRCCODE='::ImagePadder::_reportOldNewImageShape
# HISTORY >s'
# HISTORY New  size => [1730, 1730, 1, 1]
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::image::rotate'
# HISTORY Ran ia.rotate
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::image::rotate'
# HISTORY ia.rotate(outfile="", shape=[1730,1730,1,1], pa={...}, region=[], mask=[
# HISTORY >], method="cubic", decimate=0, replicate=false, dropdeg=false, overwrit
# HISTORY >=false, stretch=false)
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::BeamManipulator::rotate'
# HISTORY Ran ia.rotatebeam
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::BeamManipulator::rotate'
# HISTORY ia.rotatebeam(angle={...})
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::BeamManipulator::rotate'
# HISTORY Original Temporary_Image restoring beam: major: 0.265288 arcsec, minor:
# HISTORY > 0.203718 arcsec, pa: -68.5533 deg
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::BeamManipulator::rotate'
# HISTORY New Temporary_Image restoring beam: major: 0.265288 arcsec, minor: 0.203
# HISTORY >718 arcsec, pa: -68.5533 deg
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::setcoordsys'
# HISTORY Ran ia.setcoordsys
# HISTORY 2019-04-02T18:46:30 INFO SRCCODE='::setcoordsys'
# HISTORY ia.setcoordsys(csys={...})
# HISTORY 2019-04-02T18:46:31 INFO SRCCODE='::image::crop'
# HISTORY Ran ia.crop
# HISTORY 2019-04-02T18:46:31 INFO SRCCODE='::image::crop'
# HISTORY ia.crop(outfile="c2d_989_StokesI_clean_selfcal_v2_pbcor_J2000.image", ax
# HISTORY >es=[0,1], overwrite=false, region=[], box="", chans="", stokes="", mask
# HISTORY >"", stretch=false, wantreturn=true)
# HISTORY 2019-04-02T18:46:31 INFO SRCCODE='::ImageCropper::_reportOldNewImageShap
# HISTORY >es'
# HISTORY Original Temporary_Image size => [1730, 1730, 1, 1]
# HISTORY 2019-04-02T18:46:31 INFO SRCCODE='::ImageCropper::_reportOldNewImageShap
# HISTORY >es'
# HISTORY New c2d_989_StokesI_clean_selfcal_v2_pbcor_J2000.image size => [1726, 17
# HISTORY >26, 1, 1]
# HISTORY CASA END LOGTABLE

# %%
raise SystemExit("Stop here")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop here
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/CARTA FILES/BAND6/load_carta_data_band6.py"

# %%
reccomended_step_count(StokesI_header)

# %%
vector_lw = 3

# %% [markdown]
# # Stokes I and Polarized Intensity Plot with Vectors

# %%
fig, ax = create_stokes_i_plus_one_base_plot('Band 6', StokesI_wcs, StokesI_stretched_mJy, 
                                             normalized_cbar_ticks, StokesI_unstretched_cbar_ticks, 
                                             POLI_mJy, 'Polarized Intensity (mJy/beam)',
                                             soft_colormap_v2, 
                                             xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
                                             BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                                             max_length_pix, reference_fraction, label = 'wavelength')

for i in range(2):
    for row in vector_data_actual_cartesian:
        ax[i].plot([row[0], row[1]], [row[2], row[3]], color='black', lw = vector_lw)
    
    
    
plt.savefig(writeup_image_folder_path + '/StokesI_POLI/' + "IRS63_StokesI_POLI_vectors_BAND6.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
# fig, ax = create_stokes_i_base_plot('Band 6', 
#                                     StokesI_wcs, StokesI_stretched_mJy, 
#                                     soft_colormap_v2, 
#                               normalized_cbar_ticks, StokesI_unstretched_cbar_ticks, 
#                               xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
#                               BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
#                               max_length_pix, reference_fraction, label = 'wavelength',
#                             text_fs = 50, 
#                               axis_labels = False,
#                               x_label = False,
#                               y_label = False,
#                               x_num = False,
#                               y_num = False,
#                               full_axis_labels = False,
#                              cbar_on = False,
#                                     reference_lw = 5,
#                             beam_lw = 4,
#                         spline_lw = 3,
#                                    major_tick_length = 15)

# first_real = True
# for row in vector_data_actual_cartesian:
#     ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, 
#             label='Polarization' if first_real else None)
    
#     first_real = False

    
    
    

# ax.legend(fontsize = 50,
#          loc = 'lower right')


# plt.savefig(poster_image_folder_path + "IRS63_StokesI_BAND6_poster.png", 
#             dpi=300, 
#             transparent=True)

# %%
fig, ax = create_base_plot('Band 6', 
                           StokesI_wcs, 
                           POLI_mJy, 'Polarized Intensity (mJy/beam)', 
                           soft_colormap_no_red, 
                           xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
                           BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                           max_length_pix, reference_fraction,
                           label ='wavelength', 
                           plot_for_slides = True)


first_real = True
for row in vector_data_actual_cartesian:
    ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, 
            label='Real' if first_real else None)
    first_real = False
    


plt.savefig(slideshow_image_folder_path + '/POLI/'+ "IRS63_POLI_BAND6_slides.jpeg", 
            dpi=300, 
            bbox_inches='tight')

# %%
# raise SystemExit("Stop here")

# %% [markdown]
# # Slices Along Major and Minor Axes

# %%
major_data_StokesI, major_offset_arcsec_StokesI, minor_data_StokesI, minor_offset_arcsec_StokesI, slices_points = run_slices(StokesI_mJy, 
                                                                                                                             StokesI_header,
                                                                                                                             StokesI_wcs,
                                                                                                                             carta_major_data_mJy_StokesI, 
                                                                                                                             carta_minor_data_mJy_StokesI,
                                                                                                                             carta_minor_offset_StokesI,
                                                                                                                             carta_major_offset_StokesI,
                                                                                                                             'Band 6',
                                                                                                                             print_statement = False)

# %%
major_data_POLI, major_offset_arcsec_POLI, minor_data_POLI, minor_offset_arcsec_POLI, _ = run_slices(POLI_mJy, 
                                                                                                     StokesI_header,
                                                                                                     StokesI_wcs, 
                                                                                                     carta_major_data_mJy_POLI,
                                                                                                     carta_minor_data_mJy_POLI,
                                                                                                     carta_minor_offset_POLI,
                                                                                                     carta_major_offset_POLI,
                                                                                                     'Band 6',
                                                                                                     print_statement = False)

# %%
major_data_POLF, major_offset_arcsec_POLF, minor_data_POLF, minor_offset_arcsec_POLF, _ = run_slices(POLF, 
                                                                                                     StokesI_header,
                                                                                                     StokesI_wcs, 
                                                                                                     carta_major_data_POLF,
                                                                                                     carta_minor_data_POLF,
                                                                                                     carta_minor_offset_POLF,
                                                                                                     carta_major_offset_POLF,
                                                                                                     'Band 6', 
                                                                                                     print_statement = True)

# %%
major_x, major_y, minor_x, minor_y = slices_points

# %%
fig, ax = create_base_plot('Band 6', StokesI_wcs, POLI_mJy, 'Polarized Intensity (mJy/beam)', soft_colormap_v2, 
                           xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
                           BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                           max_length_pix, reference_fraction, label = 'wavelength')


MinorAxisSlice(ax, minor_x, minor_y)


plt.savefig(image_folder_path + "WRITEUP/Slices/" + "MinorSlice_BAND6.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
# raise SystemExit("Stop here")

# %%
ax = plot_slices_along_axes(
    major_data_StokesI,
    minor_data_StokesI,
    carta_major_data_mJy_StokesI,
    carta_minor_data_mJy_StokesI,
    major_offset_arcsec_StokesI,
    minor_offset_arcsec_StokesI,
    carta_major_offset_StokesI,
    carta_minor_offset_StokesI,
    BMAJ_deg, BMIN_deg, 
    y_label="Stokes I (mJy/beam)",
    type_of_plot="Line",  # or "Scatter",
    cb_friendly = False,
    vline = True,
    fit_slices = True,
    plot_carta = False, 
)

# plt.savefig(image_folder_path + "IRS63_StokesI_slice_BAND6.pdf", 
#             dpi=300, 
#             bbox_inches='tight')

# %%
ax = plot_slices_along_axes(
    major_data_POLI,
    minor_data_POLI,
    carta_major_data_mJy_POLI,
    carta_minor_data_mJy_POLI,
    major_offset_arcsec_POLI,
    minor_offset_arcsec_POLI,
    carta_major_offset_POLI,
    carta_minor_offset_POLI,
    BMAJ_deg, BMIN_deg, 
    y_label="Polarized Intensity (mJy/beam)",
    type_of_plot="Line",  # "Line" or "Scatter",
    cb_friendly = False,
    vline = True,
    fit_slices = True,
    plot_carta = False, 
)


# plt.savefig(image_folder_path + "IRS63_POLI_slice_BAND6.pdf", 
#             dpi=300, 
#             bbox_inches='tight')

# %%
len(major_data_POLF)

# %%
ax = plot_slices_along_axes(
    major_data_POLF,
    minor_data_POLF,
    carta_major_data_POLF,
    carta_minor_data_POLF,
    major_offset_arcsec_POLF,
    minor_offset_arcsec_POLF,
    carta_major_offset_POLF,
    carta_minor_offset_POLF,
    BMAJ_deg, BMIN_deg, 
    y_label="Polarized Fraction",
    type_of_plot="Line",  # "Line" or "Scatter",
    cb_friendly = False,
    vline = True,
    fit_slices = True
)


# plt.savefig(image_folder_path + "IRS63_POLF_slice_BAND6.pdf", 
#             dpi=300, 
#             bbox_inches='tight')

# %%
data_dict = {
    "StokesI_major"         : major_data_StokesI,
    "StokesI_offset_major": major_offset_arcsec_StokesI,
    "StokesI_minor"         : minor_data_StokesI,
    "StokesI_offset_minor": minor_offset_arcsec_StokesI
}

# Convert to DataFrame
df = pd.DataFrame(data_dict)

# Save to CSV
df.to_csv(band6_carta_folder_path + "IRS63_my_slice_StokesI_BAND6.csv", index=False)

# %%
data_dict = {
    "POLI_major"         : major_data_POLI,
    "POLI_offset_major": major_offset_arcsec_POLI,
    "POLI_minor"         : minor_data_POLI,
    "POLI_offset_minor": minor_offset_arcsec_POLI
}

# Convert to DataFrame
df = pd.DataFrame(data_dict)

# Save to CSV
df.to_csv(band6_carta_folder_path + "IRS63_my_slice_POLI_BAND6.csv", index=False)

# %%
data_dict = {
    "POLF_major"         : major_data_POLF,
    "POLF_offset_major": major_offset_arcsec_POLF,
    "POLF_minor"         : minor_data_POLF,
    "POLF_offset_minor": minor_offset_arcsec_POLF
}

# Convert to DataFrame
df = pd.DataFrame(data_dict)

# Save to CSV
df.to_csv(band6_carta_folder_path + "IRS63_my_slice_POLF_BAND6.csv", index=False)

# %%
# raise SystemExit("Stop here")

# %% [markdown]
# # Fitting the slices
#
#
# $I(r) \propto r^\alpha$
#
# Take log of both sides:
# $\log_{10}(I(r))=\alpha \log_{10}(r)+C$

# %% [markdown]
# We need to comvert the data from mJy/beam to mJy/arcsec$^2$ (or radians will also work).
#
# We can calculate the beam area with the equation:
# $1.113 \cdot BMAJ \cdot BMIN$,
# where $BMAJ$ and $BMIN$

# %% [markdown]
# # Ratio Models

# %%
_, vector_data_plotting_grid, vector_data_list_100U_to_100A, testing_vector_angles = ratio_model(StokesQ_grid_100Uniform, StokesU_grid_100Uniform,
                                                                                              StokesQ_grid_100Azimuthal, StokesU_grid_100Azimuthal,
                                                                                              ny, nx,
                                                                                              vector_length_pix_const,
                                                                                              POLI_mJy, POLI_err_mJy, 
                                                                                              PA_err_deg,
                                                                                              'Band 6',
                                                                                              # step = 10,
                                                                                              )

# %%
ax = plot_ratio_grid(POLI_mJy,
                    StokesI_wcs, soft_colormap_v2, 
                    xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
                    BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                    max_length_pix, reference_fraction,
                    vector_data_actual_cartesian, vector_data_plotting_grid)

# %% [markdown]
# ## Find the best one

# %%
min_index = find_best_fit_ratio_model(vector_angle_actual_sky, testing_vector_angles)

# %%
# raise SystemExit("Stop here")

# %%
fig, ax = create_base_plot('Band 6', StokesI_wcs, POLI_mJy, 'Polarized Intensity (mJy/beam)' , 
                           soft_colormap_no_red, 
                           xmin, xmax , ymin, ymax, reference_length_pix, reference_length_AU,
                           BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                           max_length_pix, reference_fraction, label = 'wavelength')

# Add vector plots (Best Model: black)
for i, row in enumerate(vector_data_list_100U_to_100A[min_index]):
    if i == 0:
        ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, label='Best Model')
    else:
        ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5)

# Plot actual vector data (Real: red)
for i, row in enumerate(vector_data_actual_cartesian):
    if i == 0:
        ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5, label='Real')
    else:
        ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5)

# Show legend
ax.legend(fontsize=legend_title_fs, loc = 'lower right')


plt.savefig(writeup_image_folder_path + '/Ratio/' + "IRS63_best_ratio_BAND6.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
# fig, ax = create_base_plot(StokesI_wcs, 
#                            POLI_mJy, 'Polarized Intensity (mJy/beam)', 
#                            soft_colormap_no_red, 
#                            xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
#                            BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
#                            max_length_pix, reference_fraction,
#                            cbar_fs = 40,
#                            axis_label_fs = 40,
#                            axis_num_fs = 21,
#                            cbar_orientation = 'horizontal',
#                            cbar_pad = 0.1,
#                            cbar_shrink = 0.9,
#                            fig_size_x = 12,
#                            fig_size_y = 14,
#                            text_fs = 40,
#                            y_label = True, y_num = False,
#                            x_label = True, x_num = False, 
#                            full_axis_labels = False,
#                            cbar_num_fs = 40,
#                            line_y_frac = 0.05)




# # Plot actual vector data (Real: red)
# for i, row in enumerate(vector_data_actual_cartesian):
#     if i == 0:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, label='Real')
#     else:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5)
        
        
# # Add vector plots (Best Model: black)
# for i, row in enumerate(vector_data_list_100U_to_100A[min_index]):
#     if i == 0:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5, label='Model')
#     else:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5)


# # Show legend
# ax.legend(fontsize = 35,
#          loc = 'upper left')

# plt.savefig(slideshow_image_folder_path + "IRS63_best_ratio_BAND6_slides.jpeg", 
#             dpi=300, 
#             bbox_inches='tight')

# %% [markdown]
# # Gaussian Model

# %%
phi_values = [2, 3, 4, 5, 6, 7]


BMAJ_values_pix =  np.array([10, 20, 30, 40, 50]) # + np.array(BMAJ_pix, dtype=int)
BMIN_values_pix =  np.array([10, 20, 30, 40, 50]) # + np.array(BMIN_pix, dtype=int)

# Print results
print(f'The BMAJ pix values we will test are: {BMAJ_values_pix}')
print(f'The BMIN pix values we will test are: {BMIN_values_pix}')

# %%
gaussian_values, gaussian_results, vector_data_gaussian_best, GaussianUniformRatios_best = run_gaussian_model(major_angle_rad_cartesian_band6, phi_values, 
                                                                                                              BMAJ_values_pix, BMIN_values_pix, 
                                                                                                              RA_centre_pix, Dec_centre_pix, 
                                                                                                              StokesQ_grid_100Uniform, StokesU_grid_100Uniform,
                                                                                                              StokesQ_grid_100Azimuthal, StokesU_grid_100Azimuthal,
                                                                                                              vector_angle_actual_sky,
                                                                                                              ny, nx, 
                                                                                                              POLI_mJy, POLI_err_mJy, 
                                                                                                              PA_err_deg,
                                                                                                              'Band 6',
                                                                                                              print_statements = True)

# %%
top5 = sorted(gaussian_values, key=lambda x: x[3])[:5]

top5

# %%
best = top5[0]


# Convert to DataFrame
df = pd.DataFrame([best], columns=["phi", "BMAJ", "BMIN", "chi2"])

# Save
save_path = os.path.join(band6_data_folder_path, "best_gaussian_params.csv")
df.to_csv(save_path, index=False)

df

# %%
path = band6_data_folder_path


save_path = os.path.join(
    path,
    "GaussianUniformRatios_best.npy"
)

np.save(save_path, GaussianUniformRatios_best)


save_path = os.path.join(
    path,
    "vector_data_actual_cartesian.npy"
)

np.save(save_path, vector_data_actual_cartesian)


save_path = os.path.join(
    path,
    "vector_data_gaussian_best.npy"
)

np.save(save_path, vector_data_gaussian_best)

# %%
fig, ax = create_base_plot(
    'Band 6',
    StokesI_wcs,
    GaussianUniformRatios_best,
    'Gaussian Uniform Ratio',
    soft_colormap_no_red,
    xmin, xmax, ymin, ymax,
    reference_length_pix, reference_length_AU,
    BMAJ_pix, BMIN_pix, BPA_deg_cartesian,
    max_length_pix, reference_fraction,
    label=None
)

# %%
fig, ax = create_base_plot('Band 6', StokesI_wcs, 
                           POLI_mJy, 'Polarized Intensity (mJy/beam)', 
                           soft_colormap_no_red, 
                           xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
                           BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
                           max_length_pix, reference_fraction, label = 'wavelength')

first_real = True
for row in vector_data_actual_cartesian:
    ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, 
            label='Real' if first_real else None)
    first_real = False
    
    
# Add vector plots, ensuring the label appears only once
first_best_model = True
for row in vector_data_gaussian_best:
    ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5, 
            label='Best Gaussian Model' if first_best_model else None)
    first_best_model = False

ax.legend(fontsize = legend_text_fs, loc = 'lower right')


plt.savefig(writeup_image_folder_path + '/Gaussian/' + "IRS63_best_gaussian_BAND6.pdf", 
            dpi=300, 
            bbox_inches='tight')

# %%
# fig, ax = create_base_plot(StokesI_wcs, 
#                            POLI_mJy, 'Polarized Intensity (mJy/beam)', 
#                            soft_colormap_no_red, 
#                            xmin, xmax, ymin, ymax, reference_length_pix, reference_length_AU,
#                            BMAJ_pix, BMIN_pix, BPA_deg_cartesian, 
#                            max_length_pix, reference_fraction,
#                            cbar_fs = 40,
#                            axis_label_fs = 40,
#                            axis_num_fs = 21,
#                            cbar_orientation = 'horizontal',
#                            cbar_pad = 0.1,
#                            cbar_shrink = 0.9,
#                            fig_size_x = 12,
#                            fig_size_y = 14,
#                            text_fs = 40,
#                            y_label = True, y_num = False,
#                            x_label = True, x_num = False, 
#                            full_axis_labels = False,
#                            cbar_num_fs = 40,
#                            line_y_frac = 0.05)



# # Plot actual vector data (Real: red)
# for i, row in enumerate(vector_data_actual_cartesian):
#     if i == 0:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5, label='Real')
#     else:
#         ax.plot([row[0], row[1]], [row[2], row[3]], color='black', lw=5)
        
        
# first_best_model = True
# for row in vector_data_gaussian_best:
#     ax.plot([row[0], row[1]], [row[2], row[3]], color='red', lw=5, 
#             label='Model' if first_best_model else None)
#     first_best_model = False


# # Show legend
# ax.legend(fontsize = 35,
#          loc = 'upper left')

# plt.savefig(slideshow_image_folder_path + "IRS63_best_guassian_BAND6_slides.jpeg", 
#             dpi=300, 
#             bbox_inches='tight')

# %% [markdown]
# ## Average POLF when Scattering

# %%
get_all_POLF_and_save(StokesI_mJy, POLI_mJy, POLF, GaussianUniformRatios_best, 'Band 6', gaussian_tolerance = 0.001)

# %% [markdown]
# add more:
#
# equal ellipse at centre, beam at centre

# %% [markdown]
# ## Analyze Gaussian

# %%
analyze_gaussian_averages_vs_chi2(gaussian_values, phi_values, BMAJ_values_pix, BMIN_values_pix)

# %%
plot_2d_contours_for_gaussian(gaussian_values, phi_values, BMAJ_values_pix, BMIN_values_pix, 'phi', soft_colormap_v2)

# %%
plot_2d_contours_for_gaussian(gaussian_values, phi_values, BMAJ_values_pix, BMIN_values_pix, 'BMIN', soft_colormap_v2)

# %%
plot_2d_contours_for_gaussian(gaussian_values, phi_values, BMAJ_values_pix, BMIN_values_pix, 'BMAJ', soft_colormap_v2)

# %% [markdown]
# #####
