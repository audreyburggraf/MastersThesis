# %% [markdown]
# ## Import Stuff

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/constants.py"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
# %matplotlib inline

# %%
bands = ["Band 4 nterms2", "Band 5", "Band 6", "Band 7 nterms2"]
bands_naming = ['Band4_nterms2', 'Band5', 'Band6', 'Band7_nterms2']

lambda_bands_cm = mm_to_cm([lambda_mm[b] for b in bands])

# %% [markdown]
# ## Set $\lambda$ and $a_{max}$ we want to test

# %%
# Set up wavelength array
logwave_vals = np.linspace(0.1, 4, 10000)

lambda_dist_micron = 10**logwave_vals

lambda_dist_cm = micron_to_cm(lambda_dist_micron)

# %%
# a_max values for this plot
a_max_test_micron = [1, 100]
a_max_test_cm = micron_to_cm(a_max_test_micron)

# %%
# # a_max_dist_micron =  np.logspace(np.log10(1e0), np.log10(1e4), N_grains)

# a_max_dist_micron = np.arange(50, 501)

# N_grains = len(a_max_dist_micron)

# a_max_dist_cm = micron_to_cm(a_max_dist_micron)

# %%
f_values = [1, 0.3, 0.1, 0.01]

# %%
for f in f_values:
    
    print(rf"Now working on f = {f}")
    
    N_grains = 400
    
    a_max_f_dist_cm = micron_to_cm(1/f * np.logspace(np.log10(1e0), np.log10(1e4), N_grains))
    
    
    # Run DSHARP for this f
    P, omega, P_times_omega = run_DSHARP(f, a_max_test_cm, a_max_f_dist_cm, lambda_bands_cm, lambda_dist_cm)
    
    # Prepare data dictionary
    data = {
        "a_max_f_micron": a_max_f_dist_cm * 1e4
    }
    
    # Add per-band columns
    for i, b_name in enumerate(bands_naming): 
        data[f"P_{b_name}"] = P[:, i]
        data[f"omega_{b_name}"] = omega[:, i]
        data[f"P_times_omega_{b_name}"] = P_times_omega[:, i]
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Save to CSV with f in the filename
    f_str = str(f).replace('.', '_')  # e.g., 0.3 → '0_3' for filename
    file_name = f"P_omega_vs_amax_f_{f_str}_Zhang3Bounds.csv"
    df.to_csv(P_omega_data_folder_path + file_name, index=False)
    
    print(f"Saved {file_name}")
# Out:
# Now working on f = 1
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# Mie ... Done!
# Mie ... Done!
# Saved P_omega_vs_amax_f_1_Zhang3Bounds.csv
# Now working on f = 0.3
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# Mie ... 1 %
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:2116: UserWarning: Maximum error of 9.6%: above error tolerance
#   warnings.warn(
# Mie ... 94 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_43366/53739185.py in <module>
#       9
#      10     # Run DSHARP for this f
# ---> 11     P, omega, P_times_omega = run_DSHARP(f, a_max_test_cm, a_max_f_dist_cm, lambda_bands_cm, lambda_dist_cm)
#      12
#      13     # Prepare data dictionary
#
# ~/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/DustModelFunctions.py in run_DSHARP(f, a_max_test_cm, a_max_dist_cm, lambda_bands_cm, lambda_dist_cm)
#     245     oc, rho_g_cm3 = do.get_dsharp_mix(porosity = 1 - f)
#     246
# --> 247     res = do.get_opacities(a_max_test_cm, lambda_dist_cm, rho_g_cm3, oc)
#     248
#     249     k_abs  = res['k_abs']
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in get_opacities(a, lam, rho_s, diel_const, bhmie_function, extrapol, n_angle, extrapolate_large_grains)
#    2956     m = 4 * np.pi / 3. * rho_s * a**3
#    2957
# -> 2958     package = get_mie_coefficients(
#    2959         a, lam, diel_const,
#    2960         bhmie_function=bhmie_function, nang=n_angle,
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in get_mie_coefficients(A, LAM, diel_constants, bhmie_function, nang, extrapolate_large_grains)
#    1965         # interpolate the refr. index
#    1966         #
# -> 1967         n, k = diel_constants.nk(lam)
#    1968         #
#    1969         # define the size parameter
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in nk(self, lam)
#    1431             # calculate eps = (n + I*k)**2 for each material
#    1432             #
# -> 1433             eps = np.array([complex(*c.nk(_l))**2 for c in self.constants])
#    1434
#    1435             if self.rule.lower() == 'bruggeman':
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in <listcomp>(.0)
#    1431             # calculate eps = (n + I*k)**2 for each material
#    1432             #
# -> 1433             eps = np.array([complex(*c.nk(_l))**2 for c in self.constants])
#    1434
#    1435             if self.rule.lower() == 'bruggeman':
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in nk(self, lam)
#    1439                 def fct(x):
#    1440                     return sum(self.abundances * ((eps - x) / (eps + 2 * x)))
# -> 1441                 eps_mean[i] = complex(findroot(fct, complex(0.5, 0.5)))
#    1442             elif self.rule.lower() == 'maxwell-garnett':
#    1443                 #
#
# /opt/anaconda3/lib/python3.9/site-packages/mpmath/calculus/optimization.py in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     967             maxsteps = iterations.maxsteps
#     968         i = 0
# --> 969         for x, error in iterations:
#     970             if verbose:
#     971                 print('x:    ', x)
#
# /opt/anaconda3/lib/python3.9/site-packages/mpmath/calculus/optimization.py in __iter__(self)
#      91         f0 = f(x0)
#      92         while True:
# ---> 93             f1 = f(x1)
#      94             l = x1 - x0
#      95             if not l:
#
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py in fct(x)
#    1438                 #
#    1439                 def fct(x):
# -> 1440                     return sum(self.abundances * ((eps - x) / (eps + 2 * x)))
#    1441                 eps_mean[i] = complex(findroot(fct, complex(0.5, 0.5)))
#    1442             elif self.rule.lower() == 'maxwell-garnett':
#
# /opt/anaconda3/lib/python3.9/site-packages/mpmath/ctx_mp_python.py in __div__(s, t)
#     521                 return v
#     522         v = new(cls)
# --> 523         v._mpc_ = mpc_div(s._mpc_, t._mpc_, prec, rounding)
#     524         return v
#     525
#
# /opt/anaconda3/lib/python3.9/site-packages/mpmath/libmp/libmpc.py in mpc_div(z, w, prec, rnd)
#     197     wp = prec + 10
#     198     # mag = c*c + d*d
# --> 199     mag = mpf_add(mpf_mul(c, c), mpf_mul(d, d), wp)
#     200     # (a*c+b*d)/mag, (b*c-a*d)/mag
#     201     t = mpf_add(mpf_mul(a,c), mpf_mul(b,d), wp)
#
# /opt/anaconda3/lib/python3.9/site-packages/mpmath/libmp/libmpf.py in gmpy_mpf_mul(s, t, prec, rnd)
#     848     return from_man_exp(man, exp, prec, rnd)
#     849
# --> 850 def gmpy_mpf_mul(s, t, prec=0, rnd=round_fast):
#     851     """Multiply two raw mpfs"""
#     852     ssign, sman, sexp, sbc = s
#
# KeyboardInterrupt:
