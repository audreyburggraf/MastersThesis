# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/constants.py"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
import dsharp_opac as opacity

from matplotlib.ticker import ScalarFormatter

from scipy.stats import powerlaw

# %%
f_values = []
rho_values = []

for f in (1, 0.75, 0.5, 0.3, 0.25, 0.1):

    oc, rho_g_cm3 = do.get_dsharp_mix(porosity=1 - f)

    f_values.append(f)
    rho_values.append(rho_g_cm3)
# Out:
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum

# %%
for f, rho in zip(f_values, rho_values):
    print(f'f = {f}, rho = {rho:.3f}')
# Out:
# f = 1, rho = 1.675
# f = 0.75, rho = 1.256
# f = 0.5, rho = 0.838
# f = 0.3, rho = 0.503
# f = 0.25, rho = 0.419
# f = 0.1, rho = 0.168

# %%
f = 1

oc, rho_g_cm3 = do.get_dsharp_mix(porosity = 1 - f)

print(rf'{rho_g_cm3:.2f}')
# Out:
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# 1.68

# %%
oc

# %%
f = 0.75

oc, rho_g_cm3 = do.get_dsharp_mix(porosity = 1 - f)

print(rf'{rho_g_cm3:.2f}')
# Out:
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# 1.26

# %%
f = 0.5

oc, rho_g_cm3 = do.get_dsharp_mix(porosity = 1 - f)

print(rf'{rho_g_cm3:.2f}')
# Out:
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# 0.84

# %%
f = 0.25

oc, rho_g_cm3 = do.get_dsharp_mix(porosity = 1 - f)

print(rf'{rho_g_cm3:.2f}')
# Out:
# Please cite Warren & Brandt (2008) when using these optical constants
# Please cite Draine 2003 when using these optical constants
# Reading opacities from troilitek
# Please cite Henning & Stognienko (1996) when using these optical constants
# Reading opacities from organicsk
# Please cite Henning & Stognienko (1996) when using these optical constants
# | material                            | volume fractions | mass fractions |
# |-------------------------------------|------------------|----------------|
# | Water Ice (Warren & Brandt 2008)    | 0.3642           | 0.2            |
# | Astronomical Silicates (Draine 2003)| 0.167            | 0.329          |
# | Troilite (Henning)                  | 0.02578          | 0.07434        |
# | Organics (Henning)                  | 0.443            | 0.3966         |
# using Maxwell-Garnett mixing: first component should be host material (= matrix)
#     matrix = Vacuum
# 0.42

# %% [markdown]
# # Next chunk

# %%
# Set up wavelength array
logwave_vals = np.linspace(0.1, 4, 10000)

lambda_dist_micron = 10**logwave_vals

lambda_dist_cm = micron_to_cm(lambda_dist_micron)

# %%
# a_max values for this plot
a_max_test_micron = [1, 100]
a_max_test_cm = micron_to_cm(a_max_test_micron)

# %%
res = do.get_opacities(a_max_test_cm, lambda_dist_cm, rho_g_cm3, oc)

res
# Out:
# Mie ... Done!
# {'q_abs': array([[4.86326854e-02, 4.85905342e-02, 4.85484347e-02, ...,
#          5.53970301e-07, 5.53160437e-07, 5.52338573e-07],
#         [9.74922739e-01, 9.74941060e-01, 9.74870282e-01, ...,
#          5.54556707e-05, 5.53744937e-05, 5.52921159e-05]]),
#  'q_sca': array([[7.19564650e-01, 7.18237853e-01, 7.16913212e-01, ...,
#          9.08162092e-15, 9.04906006e-15, 9.01661469e-15],
#         [1.05801118e+00, 1.05812968e+00, 1.05833028e+00, ...,
#          9.07570085e-07, 9.04317187e-07, 9.01075811e-07]]),
#  'g': array([[9.04846463e-01, 9.04694013e-01, 9.04541078e-01, ...,
#          7.14599805e-08, 6.53961890e-08, 7.09525656e-08],
#         [9.91458432e-01, 9.91460603e-01, 9.91455087e-01, ...,
#          6.95509691e-04, 6.94261658e-04, 6.93015859e-04]]),
#  'S1': array([[[ 4.78379479e+00-9.58098233e+00j,
#            7.61613372e-01-4.63926900e-01j,
#           -1.62369458e-01-3.40974422e-02j,
#            3.43437942e-01-7.14244270e-02j,
#           -1.87001587e-01+1.09301143e-01j],
#          [ 4.76670032e+00-9.55756899e+00j,
#            7.63211385e-01-4.70331833e-01j,
#           -1.64693361e-01-2.98675899e-02j,
#            3.45274687e-01-7.48259147e-02j,
#           -1.82931535e-01+1.09854357e-01j],
#          [ 4.74966550e+00-9.53420709e+00j,
#            7.64792579e-01-4.76710745e-01j,
#           -1.66995136e-01-2.56503817e-02j,
#            3.47062092e-01-7.82108447e-02j,
#           -1.78845301e-01+1.10379095e-01j],
#          ...,
#          [ 5.48714442e-14-3.67330356e-11j,
#            5.48714427e-14-3.67330346e-11j,
#            5.48714391e-14-3.67330322e-11j,
#            5.48714355e-14-3.67330300e-11j,
#            5.48714341e-14-3.67330291e-11j],
#          [ 5.46928987e-14-3.66342096e-11j,
#            5.46928973e-14-3.66342088e-11j,
#            5.46928937e-14-3.66342069e-11j,
#            5.46928902e-14-3.66342047e-11j,
#            5.46928887e-14-3.66342038e-11j],
#          [ 5.45136330e-14-3.65356479e-11j,
#            5.45136316e-14-3.65356469e-11j,
#            5.45136281e-14-3.65356446e-11j,
#            5.45136245e-14-3.65356424e-11j,
#            5.45136231e-14-3.65356415e-11j]],
#
#         [[ 1.26596881e+05+2.38975976e+03j,
#           -3.90848536e+01+1.34631136e+01j,
#            2.24619597e+01-1.47655743e+01j,
#           -1.68423332e+01+2.20050032e+00j,
#           -1.06406733e+01+8.76621005e+00j],
#          [ 1.26378197e+05+2.37746283e+03j,
#           -4.35747762e+01-1.61724883e+01j,
#           -1.60290311e+01-3.50217505e+01j,
#           -3.14550117e+00-1.04264408e+00j,
#            5.41097573e-01+1.23415629e+01j,
#            7.45063615e+00+1.23215894e+01j],
#          ...,
#          [ 5.58284869e-08-3.67522482e-05j,
#            3.94709534e-08-2.59827663e-05j,
#            9.38815096e-12-2.93068866e-09j,
#           -3.94111643e-08+2.59486435e-05j,
#           -5.57276851e-08+3.66898639e-05j],
#          [ 5.56448193e-08-3.66533367e-05j,
#            3.93411097e-08-2.59128478e-05j,
#            9.34080867e-12-2.91755926e-09j,
#           -3.92816221e-08+2.58788778e-05j,
#           -5.55445257e-08+3.65912319e-05j],
#          [ 5.54604572e-08-3.65546889e-05j,
#            3.92107751e-08-2.58431155e-05j,
#            9.29348244e-12-2.90448822e-09j,
#           -3.91515888e-08+2.58092977e-05j,
#           -5.53606717e-08+3.64928622e-05j]]]),
#  'theta': array([  0.,  45.,  90., 135., 180.]),
#  'info': 'Created with the disklab package by Kees Dullemond and Til Birnstiel.\n    If you make use of this file or package, do cite the according paper\n    Dullemond & Birnstiel 2018.\n    ',
#  'rho_s': 0.4188196799280145,
#  'k_abs': array([[8.70888256e+02, 8.70133434e+02, 8.69379539e+02, ...,
#          9.92020541e-03, 9.90570281e-03, 9.89098531e-03],
#         [1.74583977e+02, 1.74587258e+02, 1.74574583e+02, ...,
#          9.93070646e-03, 9.91616972e-03, 9.90141794e-03]]),
#  'k_sca': array([[1.28855809e+04, 1.28618213e+04, 1.28381004e+04, ...,
#          1.62628836e-10, 1.62045753e-10, 1.61464739e-10],
#         [1.89463012e+02, 1.89484233e+02, 1.89520156e+02, ...,
#          1.62522822e-04, 1.61940311e-04, 1.61359862e-04]]),
#  'a': array([0.0001, 0.01  ]),
#  'lam': array([1.25892541e-04, 1.26005656e-04, 1.26118872e-04, ...,
#         9.98205416e-01, 9.99102305e-01, 1.00000000e+00])}

# %%
res['g']
# Out:
# array([[9.04846463e-01, 9.04694013e-01, 9.04541078e-01, ...,
#         7.14599805e-08, 6.53961890e-08, 7.09525656e-08],
#        [9.91458432e-01, 9.91460603e-01, 9.91455087e-01, ...,
#         6.95509691e-04, 6.94261658e-04, 6.93015859e-04]])

# %%
# a_max_dist_micron =  np.logspace(np.log10(1e0), np.log10(1e4), N_grains)

a_max_dist_micron = np.arange(50, 501)

N_grains = len(a_max_dist_micron)

a_max_dist_cm = micron_to_cm(a_max_dist_micron)

mass_grams = calculate_grain_mass(a_max_dist_cm, rho_g_cm3, "cm")

# %%
bands        = ["Band 4", "Band 4 nterms2", "Band 4 nterms2 robust -1", "Band 4 nterms2 smooth", "Band 4 nterms2 smooth B6", "Band 4 nterms2 smooth B6 B7", "Band 5", "Band 5 robust -1", "Band 5 robust -2", "Band 6", "Band 6 smooth", "Band 6 smooth B7", "Band 7 nterms2", "Band 7 nterms2 smooth", "Band 7 nterms2 smooth B6"]
bands_naming = ["Band 4", "Band4_nterms2",  "Band4_nterms2_robust_minus",  "Band4_nterms2_smooth",  "Band4_nterms2_smooth_B6",  'Band4_nterms2_smooth_B6_B7',  'Band5',  "Band5_robust_minus1", "Band5_robust_minus2", "Band6",  'Band6_smooth',  'Band6_smooth_B7',  "Band7_nterms2", 'Band7_nterms2_smooth',    'Band7_nterms2_smooth_B6']

lambda_bands_cm = mm_to_cm([lambda_mm[b] for b in bands])

res_scatter = do.get_opacities(a_max_dist_cm, lambda_bands_cm, rho_g_cm3, oc, n_angle=100)

res_scatter
# Out:
# Mie ... Done!
# {'q_abs': array([[0.00046154, 0.00046154, 0.00046154, ..., 0.00221019, 0.00221019,
#          0.00221019],
#         [0.00047088, 0.00047088, 0.00047088, ..., 0.0022572 , 0.0022572 ,
#          0.0022572 ],
#         [0.00048023, 0.00048023, 0.00048023, ..., 0.00230435, 0.00230435,
#          0.00230435],
#         ...,
#         [0.00581068, 0.00581068, 0.00581068, ..., 0.03203602, 0.03203602,
#          0.03203602],
#         [0.0058246 , 0.0058246 , 0.0058246 , ..., 0.03210193, 0.03210193,
#          0.03210193],
#         [0.00583853, 0.00583853, 0.00583853, ..., 0.03216795, 0.03216795,
#          0.03216795]]),
#  'q_sca': array([[2.88035753e-05, 2.88035753e-05, 2.88035753e-05, ...,
#          9.59533961e-04, 9.59533961e-04, 9.59533961e-04],
#         [3.11731897e-05, 3.11731897e-05, 3.11731897e-05, ...,
#          1.03763237e-03, 1.03763237e-03, 1.03763237e-03],
#         [3.36857885e-05, 3.36857885e-05, 3.36857885e-05, ...,
#          1.12033718e-03, 1.12033718e-03, 1.12033718e-03],
#         ...,
#         [1.54024171e-01, 1.54024171e-01, 1.54024171e-01, ...,
#          1.26070335e+00, 1.26070335e+00, 1.26070335e+00],
#         [1.54830869e-01, 1.54830869e-01, 1.54830869e-01, ...,
#          1.26539581e+00, 1.26539581e+00, 1.26539581e+00],
#         [1.55639091e-01, 1.55639091e-01, 1.55639091e-01, ...,
#          1.27008468e+00, 1.27008468e+00, 1.27008468e+00]]),
#  'g': array([[0.00392686, 0.00392686, 0.00392686, ..., 0.0228471 , 0.0228471 ,
#          0.0228471 ],
#         [0.00408544, 0.00408544, 0.00408544, ..., 0.02376905, 0.02376905,
#          0.02376905],
#         [0.00424715, 0.00424715, 0.00424715, ..., 0.02470922, 0.02470922,
#          0.02470922],
#         ...,
#         [0.41494738, 0.41494738, 0.41494738, ..., 0.83490875, 0.83490875,
#          0.83490875],
#         [0.41668104, 0.41668104, 0.41668104, ..., 0.83518771, 0.83518771,
#          0.83518771],
#         [0.41841637, 0.41841637, 0.41841637, ..., 0.83546595, 0.83546595,
#          0.83546595]]),
#  'S1': array([[[2.74348174e-06-4.94015331e-04j, 2.74348006e-06-4.94015033e-04j,
#           2.74347502e-06-4.94014140e-04j, ...,
#           2.71688403e-06-4.89300733e-04j, 2.71687902e-06-4.89299845e-04j,
#           2.71687735e-06-4.89299550e-04j],
#          [2.74348174e-06-4.94015331e-04j, 2.74348006e-06-4.94015033e-04j,
