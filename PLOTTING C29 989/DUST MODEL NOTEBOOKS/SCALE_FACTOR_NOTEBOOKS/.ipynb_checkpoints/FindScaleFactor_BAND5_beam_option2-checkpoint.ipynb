# %% [markdown]
# # Load intro stuff

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/constants.py"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# %run "/Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/FUNCTIONS/load_functions"
# Out:
# fortran mie routines unavailable
# /opt/anaconda3/lib/python3.9/site-packages/dsharp_opac/dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %%
# VLA k band 9 mm (ish)
bands = ["Band 4 nterms2 smooth B6 B7", "Band 5", "Band 6 smooth B7", "Band 7 nterms2 smooth B6"]
bands_naming = ['Band4_nterms2_smooth_B6_B7', 'Band5', 'Band6_smooth_B7', 'Band7_nterms2_smooth_B6']
bands_labels = ['Band 4', 'Band 5', 'Band 6', 'Band 7']

band_colors = [alma_band_colors[b] for b in bands]
ms = [alma_band_ms[b] for b in bands]

# %%
df_POLF = load_POLF(bands, print_things = True)
# Out:
# Band = Band 4 nterms2 smooth
# Band = Band 5
# Band = Band 6 smooth
# Band = Band 7 nterms2 smooth

# %% [markdown]
# # Choose porosity values we want to test

# %%
# These are the porosity values we are going to look at
# all_f_values = [1, 0.75, 0.5, 0.3, 0.25, 0.1, 0.01]

# %%
csv_files = {
    1:   "P_omega_vs_amax_f_1_CustomBounds.csv",
    0.75:   "P_omega_vs_amax_f_0_75_CustomBounds.csv",
    0.5:   "P_omega_vs_amax_f_0_5_CustomBounds.csv",
    0.25:   "P_omega_vs_amax_f_0_25_CustomBounds.csv",
    0.3: "P_omega_vs_amax_f_0_3_CustomBounds.csv",
    0.1: "P_omega_vs_amax_f_0_1_CustomBounds.csv",
#     0.01:"P_omega_vs_amax_f_0_01_CustomBounds.csv"
}

# %% [markdown]
# # Find the scaling factor

# %%
# def find_sf_v2(a_max_f_dist_micron, P_times_omega, df_POLF, print_results=False):

#     # We are looking at the POLF from the mean/average method, none others 
#     POLF_obs = df_POLF['POLF_Gaussian']

#     # Make arrays to store the median and standard deviation values 
#     sf_medians = []
#     sf_stds = []

#     # Loop over each a_max grid point
#     for i in range(len(a_max_f_dist_micron)):

#         Pw_model = P_times_omega[i, :]  # 4 bands
        
#         # Avoid divide by zero
#         valid = Pw_model > 0
        
#         sf_i = POLF_obs[valid] / Pw_model[valid]

#         sf_medians.append(np.median(sf_i))
#         sf_stds.append(np.std(sf_i))

#     sf_medians = np.array(sf_medians)
#     sf_stds = np.array(sf_stds)

#     # Choose best a_max where scatter is minimized
#     best_idx = np.argmin(sf_stds)

#     best_a_max_f = a_max_f_dist_micron[best_idx]
#     best_sf = sf_medians[best_idx]

#     # Compute predicted POLF at best solution
# #     best_POLF = P_times_omega[best_idx, :] * best_sf

#     if print_results:
#         print("Best a_max:", best_a_max_f)
#         print("Best SF:", best_sf)

#     # return values
#     return best_a_max_f, POLF_obs, best_sf

# %%
df_POLF
# Out:
#                     Band  POLF_Gaussian  POLF_maxPOLI  POLF_maxStokesI  \
# 0  Band 4 nterms2 smooth       0.568861      0.600571         0.574181
# 1                 Band 5       0.972808      1.052077         0.990896
# 2          Band 6 smooth       1.169835      1.244203         1.228605
# 3  Band 7 nterms2 smooth       0.758683      0.853261         0.829201
#
#    POLF_mean
# 0   0.581204
# 1   1.005261
# 2   1.214214
# 3   0.813715

# %%
# Storage dicts
a_max_f_dist_micron = {}
P_times_omega = {}
best_a_max_f = {}
POLF_obs = {}
best_sf = {}

# Loop through each f value
for f, fname in csv_files.items():
    print("Loading file:", P_omega_data_folder_path + fname)
    df = pd.read_csv(P_omega_data_folder_path + fname)
#     print("Columns:", df.columns)


    df = pd.read_csv(P_omega_data_folder_path + fname)

    # x-axis (grain sizes in micron)
    a_max_f_dist_micron[f] = df["a_max_f_micron"].values

    # y-values (P*omega for each band)
    P_times_omega[f] = np.column_stack([df[f"P_times_omega_{b}"].values for b in bands_naming])

    # run best_sf calculation per f
    best_a_max_f[f], POLF_obs[f], best_sf[f] = find_sf_v2(
        a_max_f_dist_micron[f], P_times_omega[f], df_POLF, print_results=False
    )
# Out:
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_1_CustomBounds.csv
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_0_75_CustomBounds.csv
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_0_5_CustomBounds.csv
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_0_25_CustomBounds.csv
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_0_3_CustomBounds.csv
# Loading file: /Users/audreyburggraf/Desktop/QUEEN'S/THESIS RESEARCH/PLOTTING C29 989/DUST MODEL NOTEBOOKS/P_omega_Data/P_omega_vs_amax_f_0_1_CustomBounds.csv

# %%
df_POLF
# Out:
#                     Band  POLF_Gaussian  POLF_maxPOLI  POLF_maxStokesI  \
# 0  Band 4 nterms2 smooth       0.568861      0.600571         0.574181
# 1                 Band 5       0.972808      1.052077         0.990896
# 2          Band 6 smooth       1.169835      1.244203         1.228605
# 3  Band 7 nterms2 smooth       0.758683      0.853261         0.829201
#
#    POLF_mean
# 0   0.581204
# 1   1.005261
# 2   1.214214
# 3   0.813715

# %% [markdown]
# # Plot for one porosity value

# %%
f_plot = 0.25

fig, ax = plot_a_vs_POLF(a_max_f_dist_micron[f_plot], 
                         P_times_omega[f_plot], 
                         best_sf[f_plot], 
                         bands, 
                         y_plot = 'af', 
                         legend = 'w sf')

ax.text(0.80, 0.90, f'sf = {best_sf[f_plot]:.2f}', transform=ax.transAxes, fontsize = 20)
ax.text(0.80, 0.80, f'f = {f_plot}', transform=ax.transAxes, fontsize = 20)

for i in range(len(bands)):
    ax.scatter(best_a_max_f[f_plot], 
               POLF_obs[f_plot][i], 
               c = band_colors[i],
               marker = ms[i], 
               s = 200)

# %% [markdown]
# # Plot for all porosity values

# %%
log_f = [1, 0.75, 0.5, 0.25, 0.3, 0.1, 0.01]
plot_sf = 1.5

# %%
f_values = [1, 0.75, 0.5, 0.25]


fig, ax = plt.subplots(1, 4, figsize=(30, 8))

for i, f in enumerate(f_values):  # loop over subplots + f keys
    print(f,f_values[i])
        
    if i == 0:
        ax[i].set_ylabel('P $\omega$', fontsize=axis_label_fs*plot_sf)
    else:
        ax[i].set_yticklabels([])
        ax[i].set_ylabel('')
        ax[i].tick_params(left=False)
        
    if f in log_f:
        ax[i].set_xscale("log")


    # x-axis label
    ax[i].set_xlabel(r'$a_{\mathrm{max}} f / \mu\mathrm{m}$', fontsize=axis_label_fs*plot_sf)

    # ticks
    ax[i].minorticks_on()
    ax[i].tick_params(axis="x", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="y", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="x", which="major", direction="in", bottom=True, top=True, length=7, labelsize=axis_num_fs*plot_sf)
    ax[i].tick_params(axis="y", which="major", direction="in", left=True, right=True, length=7, labelsize=axis_num_fs*plot_sf)

    ax[i].set_title(f'$f$ = {f:.2f}', fontsize=50)
    
    ax[i].text(0.05, 0.15, f'sf = {best_sf[f]:.2f}', transform=ax[i].transAxes, fontsize = 30)
    
    # Add the a_max to the text
    ax[i].text(0.05, 0.05, rf'$a_{{\mathrm{{max}}}}$ = {best_a_max_f[f]/f:.0f} $\mu$m', transform=ax[i].transAxes, fontsize = 30)

    # plot each band for this f
    for j, b in enumerate(bands):
        ax[i].scatter(best_a_max_f[f], 
                      POLF_obs[f][j],
                      c=band_colors[j], 
                      marker=ms[j], s=200)

       
        ax[i].plot(a_max_f_dist_micron[f],
                   P_times_omega[f][:, j] * best_sf[f],
                   color=band_colors[j], ls='-',
                   label=f'{bands_labels[j]}',
                   lw = 3)

plt.tight_layout()
plt.subplots_adjust(wspace=0.01, hspace=0)


# Create one shared legend at the bottom
handles, labels = ax[0].get_legend_handles_labels()

fig.legend(handles, labels,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.15),  # move lower by decreasing y
           ncol=len(bands),
           fontsize=30,
           frameon=False)

plt.subplots_adjust(bottom=0.15)  # make room for legend


# ----------------------------------------------------
from matplotlib.lines import Line2D

# Create marker-only legend handles
marker_handles = []

for j in range(len(bands)):
    marker_handles.append(
        Line2D([0], [0],
               marker=ms[j],
               color='none',              # no line
               markerfacecolor=band_colors[j],
               markeredgecolor=band_colors[j],
               markersize=15,
               linestyle='None',
               label=bands_labels[j])
    )

# Add header text "POLF:"
header = Line2D([0], [0],
                linestyle='None',
                marker=None,
                label='Measured POLF:')

custom_handles = [header] + marker_handles

fig.legend(handles=custom_handles,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.25),
           ncol=len(custom_handles),
           fontsize=30,
           frameon=False,
           handlelength=0.8,
           handletextpad=0.5,
           columnspacing=1.5)
# ----------------------------------------------------


# plt.savefig(slideshow_image_folder_path + '/DustModels/'+ "Scale_factor.jpeg", 
#             dpi=500, 
#             facecolor='white',
#             bbox_inches='tight')
# Out:
# 1 1
# 0.75 0.75
# 0.5 0.5
# 0.25 0.25

# %%
# f_values = [1, 0.3, 0.1, 0.01]


# fig, ax = plt.subplots(1, 4, figsize=(30, 8))

# for i, f in enumerate(f_values):  # loop over subplots + f keys
#     if i == 0:
#         ax[i].set_ylabel('P $\omega$', fontsize=axis_label_fs*plot_sf)
#     else:
#         ax[i].set_yticklabels([])
#         ax[i].set_ylabel('')
#         ax[i].tick_params(left=False)
        
#     if f in log_f:
#         ax[i].set_xscale("log")


#     # x-axis label
#     ax[i].set_xlabel(r'$a_{\mathrm{max}} f / \mu\mathrm{m}$', fontsize=axis_label_fs*plot_sf)

#     # ticks
#     ax[i].minorticks_on()
#     ax[i].tick_params(axis="x", which="minor", direction="in", left=True, right=True, length=4)
#     ax[i].tick_params(axis="y", which="minor", direction="in", left=True, right=True, length=4)
#     ax[i].tick_params(axis="x", which="major", direction="in", bottom=True, top=True, length=7, labelsize=axis_num_fs*plot_sf)
#     ax[i].tick_params(axis="y", which="major", direction="in", left=True, right=True, length=7, labelsize=axis_num_fs*plot_sf)

#     ax[i].set_title(f'$f$ = {f:.2f}', fontsize=50)
    
#     ax[i].text(0.05, 0.15, f'sf = {best_sf[f]:.2f}', transform=ax[i].transAxes, fontsize = 30)
    
#     # Add the a_max to the text
#     ax[i].text(0.05, 0.05, rf'$a_{{\mathrm{{max}}}}$ = {best_a_max_f[f]:.0f} $\mu$m', transform=ax[i].transAxes, fontsize = 30)

#     # plot each band for this f
#     for j, b in enumerate(bands):
#         ax[i].scatter(best_a_max_f[f], best_POLF[f][j],
#                       c=band_colors[j], marker=ms[j], s=200)

#         ax[i].plot(a_max_f_dist_micron[f],
#                    P_times_omega[f][:, j] * best_sf[f],
#                    color=band_colors[j], ls='-',
#                    label=f'{bands_labels[j]}',
#                    lw = 3)

# plt.tight_layout()
# plt.subplots_adjust(wspace=0.01, hspace=0)


# # Create one shared legend at the bottom
# handles, labels = ax[0].get_legend_handles_labels()

# fig.legend(handles, labels,
#            loc='lower center',
#            bbox_to_anchor=(0.5, -0.15),  # move lower by decreasing y
#            ncol=len(bands),
#            fontsize=30,
#            frameon=False)

# plt.subplots_adjust(bottom=0.15)  # make room for legend

# %% [markdown]
# # Fit and Plot without Band 5

# %%
bands = ["Band 4 nterms2 smooth B6 B7",  "Band 6 smooth B7", "Band 7 nterms2 smooth B6"]
bands_naming = ['Band4_nterms2_smooth_B6_B7', 'Band6_smooth_B7', 'Band7_nterms2_smooth_B6']
bands_labels = ['Band 4', 'Band 6', 'Band 7']

band_colors_wo5 = [alma_band_colors[b] for b in bands_wo5]
ms_wo5 = [alma_band_ms[b] for b in bands_wo5]

df_POLF_wo5 = load_POLF(bands_wo5)

# %%
# Storage dicts
a_max_f_dist_micron_wo5 = {}
P_times_omega_wo5 = {}
best_a_max_f_wo5 = {}
POLF_obs_wo5 = {}
best_sf_wo5 = {}

# Loop through each f value
for f, fname in csv_files.items():
    df = pd.read_csv(P_omega_data_folder_path + fname)

    # x-axis (grain sizes in micron)
    a_max_f_dist_micron_wo5[f] = df["a_max_f_micron"].values

    # y-values (P*omega for each band)
    P_times_omega_wo5[f] = np.column_stack([df[f"P_times_omega_{b}"].values for b in bands_naming_wo5])

    # run best_sf calculation per f
    best_a_max_f_wo5[f], POLF_obs_wo5[f], best_sf_wo5[f] = find_sf_v2(
        a_max_f_dist_micron_wo5[f], P_times_omega_wo5[f], df_POLF_wo5, print_results=False
    )

# %%
f_values = [1, 0.75, 0.5, 0.25]


fig, ax = plt.subplots(1, 4, figsize=(30, 8))

for i, f in enumerate(f_values):  # loop over subplots + f keys
    print(f,f_values[i])
        
    if i == 0:
        ax[i].set_ylabel('P $\omega$', fontsize=axis_label_fs*plot_sf)
    else:
        ax[i].set_yticklabels([])
        ax[i].set_ylabel('')
        ax[i].tick_params(left=False)
        
    if f in log_f:
        ax[i].set_xscale("log")


    # x-axis label
    ax[i].set_xlabel(r'$a_{\mathrm{max}} f / \mu\mathrm{m}$', fontsize=axis_label_fs*plot_sf)

    # ticks
    ax[i].minorticks_on()
    ax[i].tick_params(axis="x", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="y", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="x", which="major", direction="in", bottom=True, top=True, length=7, labelsize=axis_num_fs*plot_sf)
    ax[i].tick_params(axis="y", which="major", direction="in", left=True, right=True, length=7, labelsize=axis_num_fs*plot_sf)

    ax[i].set_title(f'$f$ = {f:.2f}', fontsize=50)
    
    ax[i].text(0.05, 0.15, f'sf = {best_sf_wo5[f]:.2f}', transform=ax[i].transAxes, fontsize = 30)
    
    # Add the a_max to the text
    ax[i].text(0.05, 0.05, rf'$a_{{\mathrm{{max}}}}$ = {best_a_max_f_wo5[f]/f:.0f} $\mu$m', transform=ax[i].transAxes, fontsize = 30)

    # plot each band for this f
    for j, b in enumerate(bands_wo5):
        ax[i].scatter(best_a_max_f_wo5[f], 
                      POLF_obs_wo5[f][j],
                      c=band_colors_wo5[j], 
                      marker=ms_wo5[j], s=200)

       
        ax[i].plot(a_max_f_dist_micron_wo5[f],
                   P_times_omega_wo5[f][:, j] * best_sf_wo5[f],
                   color=band_colors_wo5[j], ls='-',
                   label=f'{bands_labels_wo5[j]}',
                   lw = 3)

plt.tight_layout()
plt.subplots_adjust(wspace=0.01, hspace=0)


# Create one shared legend at the bottom
handles, labels = ax[0].get_legend_handles_labels()

fig.legend(handles, labels,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.15),  # move lower by decreasing y
           ncol=len(bands_wo5),
           fontsize=30,
           frameon=False)

plt.subplots_adjust(bottom=0.15)  # make room for legend


# ----------------------------------------------------
from matplotlib.lines import Line2D

# Create marker-only legend handles
marker_handles = []

for j in range(len(bands_wo5)):
    marker_handles.append(
        Line2D([0], [0],
               marker=ms_wo5[j],
               color='none',              # no line
               markerfacecolor=band_colors_wo5[j],
               markeredgecolor=band_colors_wo5[j],
               markersize=15,
               linestyle='None',
               label=bands_labels_wo5[j])
    )

# Add header text "POLF:"
header = Line2D([0], [0],
                linestyle='None',
                marker=None,
                label='Measured POLF:')

custom_handles = [header] + marker_handles

fig.legend(handles=custom_handles,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.25),
           ncol=len(custom_handles),
           fontsize=30,
           frameon=False,
           handlelength=0.8,
           handletextpad=0.5,
           columnspacing=1.5)
# ----------------------------------------------------


# plt.savefig(slideshow_image_folder_path + '/DustModels/'+ "Scale_factor_without_band5.jpeg", 
#             dpi=500, 
#             facecolor='white',
#             bbox_inches='tight')
# Out:
# 1 1
# 0.75 0.75
# 0.5 0.5
# 0.25 0.25

# %% [markdown]
# # Fit and plot without 6

# %%
bands = ["Band 4 nterms2 smooth B6 B7", "Band 5",  "Band 7 nterms2 smooth B6"]
bands_naming = ['Band4_nterms2_smooth_B6_B7', 'Band5', 'Band7_nterms2_smooth_B6']
bands_labels = ['Band 4', 'Band 5', 'Band 7']

band_colors_wo6 = [alma_band_colors[b] for b in bands_wo6]
ms_wo6 = [alma_band_ms[b] for b in bands_wo6]

df_POLF_wo6 = load_POLF(bands_wo6)

# %%
# Storage dicts
a_max_f_dist_micron_wo6 = {}
P_times_omega_wo6 = {}
best_a_max_f_wo6 = {}
POLF_obs_wo6 = {}
best_sf_wo6 = {}

# Loop through each f value
for f, fname in csv_files.items():
    df = pd.read_csv(P_omega_data_folder_path + fname)

    # x-axis (grain sizes in micron)
    a_max_f_dist_micron_wo6[f] = df["a_max_f_micron"].values

    # y-values (P*omega for each band)
    P_times_omega_wo6[f] = np.column_stack([df[f"P_times_omega_{b}"].values for b in bands_naming_wo6])

    # run best_sf calculation per f
    best_a_max_f_wo6[f], POLF_obs_wo6[f], best_sf_wo6[f] = find_sf_v2(
        a_max_f_dist_micron_wo6[f], P_times_omega_wo6[f], df_POLF_wo6, print_results=False
    )

# %%
f_values = [1, 0.75, 0.5, 0.25]


fig, ax = plt.subplots(1, 4, figsize=(30, 8))

for i, f in enumerate(f_values):  # loop over subplots + f keys
    print(f,f_values[i])
        
    if i == 0:
        ax[i].set_ylabel('P $\omega$', fontsize=axis_label_fs*plot_sf)
    else:
        ax[i].set_yticklabels([])
        ax[i].set_ylabel('')
        ax[i].tick_params(left=False)
        
    if f in log_f:
        ax[i].set_xscale("log")


    # x-axis label
    ax[i].set_xlabel(r'$a_{\mathrm{max}} f / \mu\mathrm{m}$', fontsize=axis_label_fs*plot_sf)

    # ticks
    ax[i].minorticks_on()
    ax[i].tick_params(axis="x", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="y", which="minor", direction="in", left=True, right=True, length=4)
    ax[i].tick_params(axis="x", which="major", direction="in", bottom=True, top=True, length=7, labelsize=axis_num_fs*plot_sf)
    ax[i].tick_params(axis="y", which="major", direction="in", left=True, right=True, length=7, labelsize=axis_num_fs*plot_sf)

    ax[i].set_title(f'$f$ = {f:.2f}', fontsize=50)
    
    ax[i].text(0.05, 0.15, f'sf = {best_sf_wo6[f]:.2f}', transform=ax[i].transAxes, fontsize = 30)
    
    # Add the a_max to the text
    ax[i].text(0.05, 0.05, rf'$a_{{\mathrm{{max}}}}$ = {best_a_max_f_wo6[f]/f:.0f} $\mu$m', transform=ax[i].transAxes, fontsize = 30)

    # plot each band for this f
    for j, b in enumerate(bands_wo6):
        ax[i].scatter(best_a_max_f_wo6[f], 
                      POLF_obs_wo6[f][j],
                      c=band_colors_wo6[j], 
                      marker=ms_wo6[j], s=200)

       
        ax[i].plot(a_max_f_dist_micron_wo6[f],
                   P_times_omega_wo6[f][:, j] * best_sf_wo6[f],
                   color=band_colors_wo6[j], ls='-',
                   label=f'{bands_labels_wo6[j]}',
                   lw = 3)

plt.tight_layout()
plt.subplots_adjust(wspace=0.01, hspace=0)


# Create one shared legend at the bottom
handles, labels = ax[0].get_legend_handles_labels()

fig.legend(handles, labels,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.15),  # move lower by decreasing y
           ncol=len(bands_wo6),
           fontsize=30,
           frameon=False)

plt.subplots_adjust(bottom=0.15)  # make room for legend


# ----------------------------------------------------
from matplotlib.lines import Line2D

# Create marker-only legend handles
marker_handles = []

for j in range(len(bands_wo6)):
    marker_handles.append(
        Line2D([0], [0],
               marker=ms_wo6[j],
               color='none',              # no line
               markerfacecolor=band_colors_wo6[j],
               markeredgecolor=band_colors_wo6[j],
               markersize=15,
               linestyle='None',
               label=bands_labels_wo6[j])
    )

# Add header text "POLF:"
header = Line2D([0], [0],
                linestyle='None',
                marker=None,
                label='Measured POLF:')

custom_handles = [header] + marker_handles

fig.legend(handles=custom_handles,
           loc='lower center',
           bbox_to_anchor=(0.5, -0.25),
           ncol=len(custom_handles),
           fontsize=30,
           frameon=False,
           handlelength=0.8,
           handletextpad=0.5,
           columnspacing=1.5)
# ----------------------------------------------------


# plt.savefig(slideshow_image_folder_path + '/DustModels/'+ "Scale_factor_without_band5.jpeg", 
#             dpi=500, 
#             facecolor='white',
#             bbox_inches='tight')
# Out:
# 1 1
# 0.75 0.75
# 0.5 0.5
# 0.25 0.25
